# %%
# Re-import modified modules without restarting the server
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
import warnings

notebook_path = os.path.abspath(get_ipython().starting_dir)
parent_path = os.path.dirname(notebook_path)

sys.path.append(parent_path)
warnings.simplefilter("ignore")

# %%
from attribution.api_attribution import OpenAIAttributor
from attribution.experiment_logger import ExperimentLogger
from attribution.token_perturbation import (
    FixedPerturbationStrategy,
    NthNearestPerturbationStrategy,
)

# %%
attributor = OpenAIAttributor()
logger = ExperimentLogger()
attributor.compute_attributions(
    "The clock shows 9:47 PM. How many minutes 'til 10?",
    perturbation_strategy=NthNearestPerturbationStrategy(n=-1),
    attribution_strategies=["cosine"],
    logger=logger,
    perturb_word_wise=True,
)
display(logger.df_experiments)
logger.print_sentence_attribution()
logger.print_attribution_matrix(exp_id=1)
# Out:
#    exp_id                                     original_input original_output  \
# 0       1  The clock shows 9:47 PM. How many minutes 'til...     13 minutes.
#
#   perturbation_strategy  perturb_word_wise  duration
# 0    nth_nearest (n=-1)               True  9.202944
# <style type="text/css">
# #T_f04fc_row0_col0, #T_f04fc_row0_col1, #T_f04fc_row0_col2, #T_f04fc_row0_col3, #T_f04fc_row0_col4, #T_f04fc_row0_col5, #T_f04fc_row0_col6, #T_f04fc_row0_col7, #T_f04fc_row0_col8, #T_f04fc_row0_col9, #T_f04fc_row0_col10, #T_f04fc_row0_col11, #T_f04fc_row0_col12, #T_f04fc_row0_col13, #T_f04fc_row0_col14, #T_f04fc_row0_col15, #T_f04fc_row0_col16, #T_f04fc_row0_col17, #T_f04fc_row0_col18 {
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_f04fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f04fc_level0_col0" class="col_heading level0 col0" >exp_id</th>
#       <th id="T_f04fc_level0_col1" class="col_heading level0 col1" >attribution_strategy</th>
#       <th id="T_f04fc_level0_col2" class="col_heading level0 col2" >perturbation_strategy</th>
#       <th id="T_f04fc_level0_col3" class="col_heading level0 col3" >perturb_word_wise</th>
#       <th id="T_f04fc_level0_col4" class="col_heading level0 col4" >token_1</th>
#       <th id="T_f04fc_level0_col5" class="col_heading level0 col5" >token_2</th>
#       <th id="T_f04fc_level0_col6" class="col_heading level0 col6" >token_3</th>
#       <th id="T_f04fc_level0_col7" class="col_heading level0 col7" >token_4</th>
#       <th id="T_f04fc_level0_col8" class="col_heading level0 col8" >token_5</th>
#       <th id="T_f04fc_level0_col9" class="col_heading level0 col9" >token_6</th>
#       <th id="T_f04fc_level0_col10" class="col_heading level0 col10" >token_7</th>
#       <th id="T_f04fc_level0_col11" class="col_heading level0 col11" >token_8</th>
#       <th id="T_f04fc_level0_col12" class="col_heading level0 col12" >token_9</th>
#       <th id="T_f04fc_level0_col13" class="col_heading level0 col13" >token_10</th>
#       <th id="T_f04fc_level0_col14" class="col_heading level0 col14" >token_11</th>
#       <th id="T_f04fc_level0_col15" class="col_heading level0 col15" >token_12</th>
#       <th id="T_f04fc_level0_col16" class="col_heading level0 col16" >token_13</th>
#       <th id="T_f04fc_level0_col17" class="col_heading level0 col17" >token_14</th>
#       <th id="T_f04fc_level0_col18" class="col_heading level0 col18" >token_15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f04fc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f04fc_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_f04fc_row0_col1" class="data row0 col1" >cosine</td>
#       <td id="T_f04fc_row0_col2" class="data row0 col2" >nth_nearest (n=-1)</td>
#       <td id="T_f04fc_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_f04fc_row0_col4" class="data row0 col4" >The
# 0.10</td>
#       <td id="T_f04fc_row0_col5" class="data row0 col5" >clock
# -0.00</td>
#       <td id="T_f04fc_row0_col6" class="data row0 col6" >shows
# -0.00</td>
#       <td id="T_f04fc_row0_col7" class="data row0 col7" >9
# 0.18</td>
#       <td id="T_f04fc_row0_col8" class="data row0 col8" >:
# 0.18</td>
#       <td id="T_f04fc_row0_col9" class="data row0 col9" >47
# 0.18</td>
#       <td id="T_f04fc_row0_col10" class="data row0 col10" >PM
# 0.10</td>
#       <td id="T_f04fc_row0_col11" class="data row0 col11" >.
# 0.10</td>
#       <td id="T_f04fc_row0_col12" class="data row0 col12" >How
# 0.10</td>
#       <td id="T_f04fc_row0_col13" class="data row0 col13" >many
# 0.10</td>
#       <td id="T_f04fc_row0_col14" class="data row0 col14" >minutes
# 0.10</td>
#       <td id="T_f04fc_row0_col15" class="data row0 col15" >'
# 0.23</td>
#       <td id="T_f04fc_row0_col16" class="data row0 col16" >til
# 0.23</td>
#       <td id="T_f04fc_row0_col17" class="data row0 col17" >10
# 0.23</td>
#       <td id="T_f04fc_row0_col18" class="data row0 col18" >?
# 0.23</td>
#     </tr>
#   </tbody>
# </table>
# Attribution matrix for experiment 1
# Attribution Strategy: cosine
# Perturbation strategy: nth_nearest (n=-1):
# Input Tokens (Rows) vs. Output Tokens (Columns)
# <style type="text/css">
# #T_7ca7c_row0_col0, #T_7ca7c_row6_col0, #T_7ca7c_row7_col0, #T_7ca7c_row8_col0, #T_7ca7c_row9_col0, #T_7ca7c_row10_col0 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_7ca7c_row0_col1, #T_7ca7c_row1_col0, #T_7ca7c_row1_col1, #T_7ca7c_row2_col0, #T_7ca7c_row2_col1, #T_7ca7c_row3_col1, #T_7ca7c_row4_col1, #T_7ca7c_row5_col1, #T_7ca7c_row6_col1, #T_7ca7c_row7_col1, #T_7ca7c_row8_col1, #T_7ca7c_row9_col1, #T_7ca7c_row10_col1, #T_7ca7c_row11_col0, #T_7ca7c_row11_col1, #T_7ca7c_row12_col0, #T_7ca7c_row12_col1, #T_7ca7c_row13_col0, #T_7ca7c_row13_col1, #T_7ca7c_row14_col0, #T_7ca7c_row14_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_7ca7c_row0_col2, #T_7ca7c_row1_col2, #T_7ca7c_row2_col2, #T_7ca7c_row3_col2, #T_7ca7c_row4_col2, #T_7ca7c_row5_col2, #T_7ca7c_row6_col2, #T_7ca7c_row7_col2, #T_7ca7c_row8_col2, #T_7ca7c_row9_col2, #T_7ca7c_row10_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_7ca7c_row3_col0, #T_7ca7c_row4_col0, #T_7ca7c_row5_col0 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_7ca7c_row11_col2, #T_7ca7c_row12_col2, #T_7ca7c_row13_col2, #T_7ca7c_row14_col2 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7ca7c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ca7c_level0_col0" class="col_heading level0 col0" >13 (0)</th>
#       <th id="T_7ca7c_level0_col1" class="col_heading level0 col1" > minutes (1)</th>
#       <th id="T_7ca7c_level0_col2" class="col_heading level0 col2" >. (2)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ca7c_level0_row0" class="row_heading level0 row0" >The (0)</th>
#       <td id="T_7ca7c_row0_col0" class="data row0 col0" >0.294424</td>
#       <td id="T_7ca7c_row0_col1" class="data row0 col1" >-0.000000</td>
#       <td id="T_7ca7c_row0_col2" class="data row0 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ca7c_level0_row1" class="row_heading level0 row1" >clock (1)</th>
#       <td id="T_7ca7c_row1_col0" class="data row1 col0" >-0.000000</td>
#       <td id="T_7ca7c_row1_col1" class="data row1 col1" >-0.000000</td>
#       <td id="T_7ca7c_row1_col2" class="data row1 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ca7c_level0_row2" class="row_heading level0 row2" >shows (2)</th>
#       <td id="T_7ca7c_row2_col0" class="data row2 col0" >-0.000000</td>
#       <td id="T_7ca7c_row2_col1" class="data row2 col1" >-0.000000</td>
#       <td id="T_7ca7c_row2_col2" class="data row2 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ca7c_level0_row3" class="row_heading level0 row3" >9 (3)</th>
#       <td id="T_7ca7c_row3_col0" class="data row3 col0" >0.549087</td>
#       <td id="T_7ca7c_row3_col1" class="data row3 col1" >-0.000000</td>
#       <td id="T_7ca7c_row3_col2" class="data row3 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ca7c_level0_row4" class="row_heading level0 row4" >: (4)</th>
#       <td id="T_7ca7c_row4_col0" class="data row4 col0" >0.549087</td>
#       <td id="T_7ca7c_row4_col1" class="data row4 col1" >-0.000000</td>
#       <td id="T_7ca7c_row4_col2" class="data row4 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ca7c_level0_row5" class="row_heading level0 row5" >47 (5)</th>
#       <td id="T_7ca7c_row5_col0" class="data row5 col0" >0.549087</td>
#       <td id="T_7ca7c_row5_col1" class="data row5 col1" >-0.000000</td>
#       <td id="T_7ca7c_row5_col2" class="data row5 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ca7c_level0_row6" class="row_heading level0 row6" >PM (6)</th>
#       <td id="T_7ca7c_row6_col0" class="data row6 col0" >0.294424</td>
#       <td id="T_7ca7c_row6_col1" class="data row6 col1" >-0.000000</td>
#       <td id="T_7ca7c_row6_col2" class="data row6 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ca7c_level0_row7" class="row_heading level0 row7" >. (7)</th>
#       <td id="T_7ca7c_row7_col0" class="data row7 col0" >0.294424</td>
#       <td id="T_7ca7c_row7_col1" class="data row7 col1" >-0.000000</td>
#       <td id="T_7ca7c_row7_col2" class="data row7 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ca7c_level0_row8" class="row_heading level0 row8" >How (8)</th>
#       <td id="T_7ca7c_row8_col0" class="data row8 col0" >0.294424</td>
#       <td id="T_7ca7c_row8_col1" class="data row8 col1" >-0.000000</td>
#       <td id="T_7ca7c_row8_col2" class="data row8 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ca7c_level0_row9" class="row_heading level0 row9" >many (9)</th>
#       <td id="T_7ca7c_row9_col0" class="data row9 col0" >0.294424</td>
#       <td id="T_7ca7c_row9_col1" class="data row9 col1" >-0.000000</td>
#       <td id="T_7ca7c_row9_col2" class="data row9 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ca7c_level0_row10" class="row_heading level0 row10" >minutes (10)</th>
#       <td id="T_7ca7c_row10_col0" class="data row10 col0" >0.294424</td>
#       <td id="T_7ca7c_row10_col1" class="data row10 col1" >-0.000000</td>
#       <td id="T_7ca7c_row10_col2" class="data row10 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ca7c_level0_row11" class="row_heading level0 row11" >' (11)</th>
#       <td id="T_7ca7c_row11_col0" class="data row11 col0" >-0.000000</td>
#       <td id="T_7ca7c_row11_col1" class="data row11 col1" >-0.000000</td>
#       <td id="T_7ca7c_row11_col2" class="data row11 col2" >0.690817</td>
#     </tr>
#     <tr>
#       <th id="T_7ca7c_level0_row12" class="row_heading level0 row12" >til (12)</th>
#       <td id="T_7ca7c_row12_col0" class="data row12 col0" >-0.000000</td>
#       <td id="T_7ca7c_row12_col1" class="data row12 col1" >-0.000000</td>
#       <td id="T_7ca7c_row12_col2" class="data row12 col2" >0.690817</td>
#     </tr>
#     <tr>
#       <th id="T_7ca7c_level0_row13" class="row_heading level0 row13" >10 (13)</th>
#       <td id="T_7ca7c_row13_col0" class="data row13 col0" >-0.000000</td>
#       <td id="T_7ca7c_row13_col1" class="data row13 col1" >-0.000000</td>
#       <td id="T_7ca7c_row13_col2" class="data row13 col2" >0.690817</td>
#     </tr>
#     <tr>
#       <th id="T_7ca7c_level0_row14" class="row_heading level0 row14" >? (14)</th>
#       <td id="T_7ca7c_row14_col0" class="data row14 col0" >-0.000000</td>
#       <td id="T_7ca7c_row14_col1" class="data row14 col1" >-0.000000</td>
#       <td id="T_7ca7c_row14_col2" class="data row14 col2" >0.690817</td>
#     </tr>
#   </tbody>
# </table>

# %%
logger.print_attribution_matrix(exp_id=1, show_debug_cols=True)
# Out:
# Attribution matrix for experiment 1
# Attribution Strategy: cosine
# Perturbation strategy: nth_nearest (n=-1):
# Input Tokens (Rows) vs. Output Tokens (Columns)
# <style type="text/css">
# #T_e60a9_row0_col0, #T_e60a9_row6_col0, #T_e60a9_row7_col0, #T_e60a9_row8_col0, #T_e60a9_row9_col0, #T_e60a9_row10_col0 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_e60a9_row0_col1, #T_e60a9_row1_col0, #T_e60a9_row1_col1, #T_e60a9_row2_col0, #T_e60a9_row2_col1, #T_e60a9_row3_col1, #T_e60a9_row4_col1, #T_e60a9_row5_col1, #T_e60a9_row6_col1, #T_e60a9_row7_col1, #T_e60a9_row8_col1, #T_e60a9_row9_col1, #T_e60a9_row10_col1, #T_e60a9_row11_col0, #T_e60a9_row11_col1, #T_e60a9_row12_col0, #T_e60a9_row12_col1, #T_e60a9_row13_col0, #T_e60a9_row13_col1, #T_e60a9_row14_col0, #T_e60a9_row14_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_e60a9_row0_col2, #T_e60a9_row1_col2, #T_e60a9_row2_col2, #T_e60a9_row3_col2, #T_e60a9_row4_col2, #T_e60a9_row5_col2, #T_e60a9_row6_col2, #T_e60a9_row7_col2, #T_e60a9_row8_col2, #T_e60a9_row9_col2, #T_e60a9_row10_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_e60a9_row3_col0, #T_e60a9_row4_col0, #T_e60a9_row5_col0 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_e60a9_row11_col2, #T_e60a9_row12_col2, #T_e60a9_row13_col2, #T_e60a9_row14_col2 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e60a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e60a9_level0_col0" class="col_heading level0 col0" >13 (0)</th>
#       <th id="T_e60a9_level0_col1" class="col_heading level0 col1" > minutes (1)</th>
#       <th id="T_e60a9_level0_col2" class="col_heading level0 col2" >. (2)</th>
#       <th id="T_e60a9_level0_col3" class="col_heading level0 col3" >perturbed_input</th>
#       <th id="T_e60a9_level0_col4" class="col_heading level0 col4" >perturbed_output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e60a9_level0_row0" class="row_heading level0 row0" >The (0)</th>
#       <td id="T_e60a9_row0_col0" class="data row0 col0" >0.294424</td>
#       <td id="T_e60a9_row0_col1" class="data row0 col1" >-0.000000</td>
#       <td id="T_e60a9_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_e60a9_row0_col3" class="data row0 col3" >EStreamFrame clock shows 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_e60a9_row0_col4" class="data row0 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_e60a9_level0_row1" class="row_heading level0 row1" >clock (1)</th>
#       <td id="T_e60a9_row1_col0" class="data row1 col0" >-0.000000</td>
#       <td id="T_e60a9_row1_col1" class="data row1 col1" >-0.000000</td>
#       <td id="T_e60a9_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_e60a9_row1_col3" class="data row1 col3" >Theur shows 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_e60a9_row1_col4" class="data row1 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_e60a9_level0_row2" class="row_heading level0 row2" >shows (2)</th>
#       <td id="T_e60a9_row2_col0" class="data row2 col0" >-0.000000</td>
#       <td id="T_e60a9_row2_col1" class="data row2 col1" >-0.000000</td>
#       <td id="T_e60a9_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_e60a9_row2_col3" class="data row2 col3" >The clocketooth 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_e60a9_row2_col4" class="data row2 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_e60a9_level0_row3" class="row_heading level0 row3" >9 (3)</th>
#       <td id="T_e60a9_row3_col0" class="data row3 col0" >0.549087</td>
#       <td id="T_e60a9_row3_col1" class="data row3 col1" >-0.000000</td>
#       <td id="T_e60a9_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_e60a9_row3_col3" class="data row3 col3" >The clock showsDERRiHUD full PM. How many minutes 'til 10?</td>
#       <td id="T_e60a9_row3_col4" class="data row3 col4" >There are 60 minutes in an hour, so there are 60 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_e60a9_level0_row4" class="row_heading level0 row4" >: (4)</th>
#       <td id="T_e60a9_row4_col0" class="data row4 col0" >0.549087</td>
#       <td id="T_e60a9_row4_col1" class="data row4 col1" >-0.000000</td>
#       <td id="T_e60a9_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_e60a9_row4_col3" class="data row4 col3" >The clock showsDERRiHUD full PM. How many minutes 'til 10?</td>
#       <td id="T_e60a9_row4_col4" class="data row4 col4" >There are 60 minutes in an hour, so there are 60 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_e60a9_level0_row5" class="row_heading level0 row5" >47 (5)</th>
#       <td id="T_e60a9_row5_col0" class="data row5 col0" >0.549087</td>
#       <td id="T_e60a9_row5_col1" class="data row5 col1" >-0.000000</td>
#       <td id="T_e60a9_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_e60a9_row5_col3" class="data row5 col3" >The clock showsDERRiHUD full PM. How many minutes 'til 10?</td>
#       <td id="T_e60a9_row5_col4" class="data row5 col4" >There are 60 minutes in an hour, so there are 60 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_e60a9_level0_row6" class="row_heading level0 row6" >PM (6)</th>
#       <td id="T_e60a9_row6_col0" class="data row6 col0" >0.294424</td>
#       <td id="T_e60a9_row6_col1" class="data row6 col1" >-0.000000</td>
#       <td id="T_e60a9_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_e60a9_row6_col3" class="data row6 col3" >The clock shows 9:47 TusiHUD How many minutes 'til 10?</td>
#       <td id="T_e60a9_row6_col4" class="data row6 col4" >There are 13 minutes until 10 o'clock.</td>
#     </tr>
#     <tr>
#       <th id="T_e60a9_level0_row7" class="row_heading level0 row7" >. (7)</th>
#       <td id="T_e60a9_row7_col0" class="data row7 col0" >0.294424</td>
#       <td id="T_e60a9_row7_col1" class="data row7 col1" >-0.000000</td>
#       <td id="T_e60a9_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_e60a9_row7_col3" class="data row7 col3" >The clock shows 9:47 TusiHUD How many minutes 'til 10?</td>
#       <td id="T_e60a9_row7_col4" class="data row7 col4" >There are 13 minutes until 10 o'clock.</td>
#     </tr>
#     <tr>
#       <th id="T_e60a9_level0_row8" class="row_heading level0 row8" >How (8)</th>
#       <td id="T_e60a9_row8_col0" class="data row8 col0" >0.294424</td>
#       <td id="T_e60a9_row8_col1" class="data row8 col1" >-0.000000</td>
#       <td id="T_e60a9_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_e60a9_row8_col3" class="data row8 col3" >The clock shows 9:47 PM.erate many minutes 'til 10?</td>
#       <td id="T_e60a9_row8_col4" class="data row8 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_e60a9_level0_row9" class="row_heading level0 row9" >many (9)</th>
#       <td id="T_e60a9_row9_col0" class="data row9 col0" >0.294424</td>
#       <td id="T_e60a9_row9_col1" class="data row9 col1" >-0.000000</td>
#       <td id="T_e60a9_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_e60a9_row9_col3" class="data row9 col3" >The clock shows 9:47 PM. Howizu minutes 'til 10?</td>
#       <td id="T_e60a9_row9_col4" class="data row9 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_e60a9_level0_row10" class="row_heading level0 row10" >minutes (10)</th>
#       <td id="T_e60a9_row10_col0" class="data row10 col0" >0.294424</td>
#       <td id="T_e60a9_row10_col1" class="data row10 col1" >-0.000000</td>
#       <td id="T_e60a9_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_e60a9_row10_col3" class="data row10 col3" >The clock shows 9:47 PM. How manytain 'til 10?</td>
#       <td id="T_e60a9_row10_col4" class="data row10 col4" >There are 13 minutes left until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_e60a9_level0_row11" class="row_heading level0 row11" >' (11)</th>
#       <td id="T_e60a9_row11_col0" class="data row11 col0" >-0.000000</td>
#       <td id="T_e60a9_row11_col1" class="data row11 col1" >-0.000000</td>
#       <td id="T_e60a9_row11_col2" class="data row11 col2" >0.690817</td>
#       <td id="T_e60a9_row11_col3" class="data row11 col3" >

# %%
attributor = OpenAIAttributor()

input_texts = ["The clock shows 9:47 PM. How many minutes 'til 10?"]

perturbation_strategies = [
    FixedPerturbationStrategy(),
    NthNearestPerturbationStrategy(n=0),
    NthNearestPerturbationStrategy(n=-1),
    # (PerturbationStrategy.NTH_NEAREST, {"n": 10}),
]

# Initialize the logger
logger = ExperimentLogger()

# Perform the experiment
for input_text in input_texts:
    for perturbation_strategy in perturbation_strategies:
        attributor.compute_attributions(
            input_text,
            perturbation_strategy=perturbation_strategy,
            attribution_strategies=["cosine", "prob_diff"],
            logger=logger,
            perturb_word_wise=True,
        )

# Display the results
display(logger.df_experiments)
logger.print_sentence_attribution()
# Out:
#    exp_id                                     original_input original_output  \
# 0       1  The clock shows 9:47 PM. How many minutes 'til...     13 minutes.
# 1       2  The clock shows 9:47 PM. How many minutes 'til...     13 minutes.
# 2       3  The clock shows 9:47 PM. How many minutes 'til...     13 minutes.
#
#   perturbation_strategy  perturb_word_wise   duration
# 0                 fixed               True   7.927439
# 1     nth_nearest (n=0)               True    9.00721
# 2    nth_nearest (n=-1)               True  10.326304
# <style type="text/css">
# #T_9d1e3_row0_col0, #T_9d1e3_row0_col1, #T_9d1e3_row0_col2, #T_9d1e3_row0_col3, #T_9d1e3_row0_col4, #T_9d1e3_row0_col5, #T_9d1e3_row0_col6, #T_9d1e3_row0_col7, #T_9d1e3_row0_col8, #T_9d1e3_row0_col9, #T_9d1e3_row0_col10, #T_9d1e3_row0_col11, #T_9d1e3_row0_col12, #T_9d1e3_row0_col13, #T_9d1e3_row0_col14, #T_9d1e3_row0_col15, #T_9d1e3_row0_col16, #T_9d1e3_row0_col17, #T_9d1e3_row0_col18, #T_9d1e3_row1_col0, #T_9d1e3_row1_col1, #T_9d1e3_row1_col2, #T_9d1e3_row1_col3, #T_9d1e3_row1_col4, #T_9d1e3_row1_col5, #T_9d1e3_row1_col6, #T_9d1e3_row1_col7, #T_9d1e3_row1_col8, #T_9d1e3_row1_col9, #T_9d1e3_row1_col10, #T_9d1e3_row1_col11, #T_9d1e3_row1_col12, #T_9d1e3_row1_col13, #T_9d1e3_row1_col14, #T_9d1e3_row1_col15, #T_9d1e3_row1_col16, #T_9d1e3_row1_col17, #T_9d1e3_row1_col18, #T_9d1e3_row2_col0, #T_9d1e3_row2_col1, #T_9d1e3_row2_col2, #T_9d1e3_row2_col3, #T_9d1e3_row2_col4, #T_9d1e3_row2_col5, #T_9d1e3_row2_col6, #T_9d1e3_row2_col7, #T_9d1e3_row2_col8, #T_9d1e3_row2_col9, #T_9d1e3_row2_col10, #T_9d1e3_row2_col11, #T_9d1e3_row2_col12, #T_9d1e3_row2_col13, #T_9d1e3_row2_col14, #T_9d1e3_row2_col15, #T_9d1e3_row2_col16, #T_9d1e3_row2_col17, #T_9d1e3_row2_col18, #T_9d1e3_row3_col0, #T_9d1e3_row3_col1, #T_9d1e3_row3_col2, #T_9d1e3_row3_col3, #T_9d1e3_row3_col4, #T_9d1e3_row3_col5, #T_9d1e3_row3_col6, #T_9d1e3_row3_col7, #T_9d1e3_row3_col8, #T_9d1e3_row3_col9, #T_9d1e3_row3_col10, #T_9d1e3_row3_col11, #T_9d1e3_row3_col12, #T_9d1e3_row3_col13, #T_9d1e3_row3_col14, #T_9d1e3_row3_col15, #T_9d1e3_row3_col16, #T_9d1e3_row3_col17, #T_9d1e3_row3_col18, #T_9d1e3_row4_col0, #T_9d1e3_row4_col1, #T_9d1e3_row4_col2, #T_9d1e3_row4_col3, #T_9d1e3_row4_col4, #T_9d1e3_row4_col5, #T_9d1e3_row4_col6, #T_9d1e3_row4_col7, #T_9d1e3_row4_col8, #T_9d1e3_row4_col9, #T_9d1e3_row4_col10, #T_9d1e3_row4_col11, #T_9d1e3_row4_col12, #T_9d1e3_row4_col13, #T_9d1e3_row4_col14, #T_9d1e3_row4_col15, #T_9d1e3_row4_col16, #T_9d1e3_row4_col17, #T_9d1e3_row4_col18, #T_9d1e3_row5_col0, #T_9d1e3_row5_col1, #T_9d1e3_row5_col2, #T_9d1e3_row5_col3, #T_9d1e3_row5_col4, #T_9d1e3_row5_col5, #T_9d1e3_row5_col6, #T_9d1e3_row5_col7, #T_9d1e3_row5_col8, #T_9d1e3_row5_col9, #T_9d1e3_row5_col10, #T_9d1e3_row5_col11, #T_9d1e3_row5_col12, #T_9d1e3_row5_col13, #T_9d1e3_row5_col14, #T_9d1e3_row5_col15, #T_9d1e3_row5_col16, #T_9d1e3_row5_col17, #T_9d1e3_row5_col18 {
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_9d1e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d1e3_level0_col0" class="col_heading level0 col0" >exp_id</th>
#       <th id="T_9d1e3_level0_col1" class="col_heading level0 col1" >attribution_strategy</th>
#       <th id="T_9d1e3_level0_col2" class="col_heading level0 col2" >perturbation_strategy</th>
#       <th id="T_9d1e3_level0_col3" class="col_heading level0 col3" >perturb_word_wise</th>
#       <th id="T_9d1e3_level0_col4" class="col_heading level0 col4" >token_1</th>
#       <th id="T_9d1e3_level0_col5" class="col_heading level0 col5" >token_2</th>
#       <th id="T_9d1e3_level0_col6" class="col_heading level0 col6" >token_3</th>
#       <th id="T_9d1e3_level0_col7" class="col_heading level0 col7" >token_4</th>
#       <th id="T_9d1e3_level0_col8" class="col_heading level0 col8" >token_5</th>
#       <th id="T_9d1e3_level0_col9" class="col_heading level0 col9" >token_6</th>
#       <th id="T_9d1e3_level0_col10" class="col_heading level0 col10" >token_7</th>
#       <th id="T_9d1e3_level0_col11" class="col_heading level0 col11" >token_8</th>
#       <th id="T_9d1e3_level0_col12" class="col_heading level0 col12" >token_9</th>
#       <th id="T_9d1e3_level0_col13" class="col_heading level0 col13" >token_10</th>
#       <th id="T_9d1e3_level0_col14" class="col_heading level0 col14" >token_11</th>
#       <th id="T_9d1e3_level0_col15" class="col_heading level0 col15" >token_12</th>
#       <th id="T_9d1e3_level0_col16" class="col_heading level0 col16" >token_13</th>
#       <th id="T_9d1e3_level0_col17" class="col_heading level0 col17" >token_14</th>
#       <th id="T_9d1e3_level0_col18" class="col_heading level0 col18" >token_15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d1e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d1e3_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_9d1e3_row0_col1" class="data row0 col1" >cosine</td>
#       <td id="T_9d1e3_row0_col2" class="data row0 col2" >fixed</td>
#       <td id="T_9d1e3_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_9d1e3_row0_col4" class="data row0 col4" >The
# 0.10</td>
#       <td id="T_9d1e3_row0_col5" class="data row0 col5" >clock
# 0.10</td>
#       <td id="T_9d1e3_row0_col6" class="data row0 col6" >shows
# -0.00</td>
#       <td id="T_9d1e3_row0_col7" class="data row0 col7" >9
# 0.18</td>
#       <td id="T_9d1e3_row0_col8" class="data row0 col8" >:
# 0.18</td>
#       <td id="T_9d1e3_row0_col9" class="data row0 col9" >47
# 0.18</td>
#       <td id="T_9d1e3_row0_col10" class="data row0 col10" >PM
# -0.00</td>
#       <td id="T_9d1e3_row0_col11" class="data row0 col11" >.
# -0.00</td>
#       <td id="T_9d1e3_row0_col12" class="data row0 col12" >How
# 0.10</td>
#       <td id="T_9d1e3_row0_col13" class="data row0 col13" >many
# 0.10</td>
#       <td id="T_9d1e3_row0_col14" class="data row0 col14" >minutes
# -0.00</td>
#       <td id="T_9d1e3_row0_col15" class="data row0 col15" >'
# -0.00</td>
#       <td id="T_9d1e3_row0_col16" class="data row0 col16" >til
# -0.00</td>
#       <td id="T_9d1e3_row0_col17" class="data row0 col17" >10
# -0.00</td>
#       <td id="T_9d1e3_row0_col18" class="data row0 col18" >?
# -0.00</td>
#     </tr>
#     <tr>
#       <th id="T_9d1e3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9d1e3_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_9d1e3_row1_col1" class="data row1 col1" >prob_diff</td>
#       <td id="T_9d1e3_row1_col2" class="data row1 col2" >fixed</td>
#       <td id="T_9d1e3_row1_col3" class="data row1 col3" >True</td>
#       <td id="T_9d1e3_row1_col4" class="data row1 col4" >The
# -0.21</td>
#       <td id="T_9d1e3_row1_col5" class="data row1 col5" >clock
# -0.22</td>
#       <td id="T_9d1e3_row1_col6" class="data row1 col6" >shows
# 0.07</td>
#       <td id="T_9d1e3_row1_col7" class="data row1 col7" >9
# 0.12</td>
#       <td id="T_9d1e3_row1_col8" class="data row1 col8" >:
# 0.12</td>
#       <td id="T_9d1e3_row1_col9" class="data row1 col9" >47
# 0.12</td>
#       <td id="T_9d1e3_row1_col10" class="data row1 col10" >PM
# 0.07</td>
#       <td id="T_9d1e3_row1_col11" class="data row1 col11" >.
# 0.07</td>
#       <td id="T_9d1e3_row1_col12" class="data row1 col12" >How
# -0.21</td>
#       <td id="T_9d1e3_row1_col13" class="data row1 col13" >many
# -0.21</td>
#       <td id="T_9d1e3_row1_col14" class="data row1 col14" >minutes
# 0.12</td>
#       <td id="T_9d1e3_row1_col15" class="data row1 col15" >'
# 0.01</td>
#       <td id="T_9d1e3_row1_col16" class="data row1 col16" >til
# 0.01</td>
#       <td id="T_9d1e3_row1_col17" class="data row1 col17" >10
# 0.07</td>
#       <td id="T_9d1e3_row1_col18" class="data row1 col18" >?
# 0.07</td>
#     </tr>
#     <tr>
#       <th id="T_9d1e3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9d1e3_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_9d1e3_row2_col1" class="data row2 col1" >cosine</td>
#       <td id="T_9d1e3_row2_col2" class="data row2 col2" >nth_nearest (n=0)</td>
#       <td id="T_9d1e3_row2_col3" class="data row2 col3" >True</td>
#       <td id="T_9d1e3_row2_col4" class="data row2 col4" >The
# -0.00</td>
#       <td id="T_9d1e3_row2_col5" class="data row2 col5" >clock
# -0.00</td>
#       <td id="T_9d1e3_row2_col6" class="data row2 col6" >shows
# -0.00</td>
#       <td id="T_9d1e3_row2_col7" class="data row2 col7" >9
# -0.00</td>
#       <td id="T_9d1e3_row2_col8" class="data row2 col8" >:
# -0.00</td>
#       <td id="T_9d1e3_row2_col9" class="data row2 col9" >47
# -0.00</td>
#       <td id="T_9d1e3_row2_col10" class="data row2 col10" >PM
# -0.00</td>
#       <td id="T_9d1e3_row2_col11" class="data row2 col11" >.
# -0.00</td>
#       <td id="T_9d1e3_row2_col12" class="data row2 col

# %%
logger.print_attribution_matrix(exp_id=1, show_debug_cols=True)
# Out:
# Attribution matrix for experiment 1
# Attribution Strategy: cosine
# Perturbation strategy: fixed:
# Input Tokens (Rows) vs. Output Tokens (Columns)
# <style type="text/css">
# #T_cb80e_row0_col0, #T_cb80e_row1_col0, #T_cb80e_row8_col0, #T_cb80e_row9_col0 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_cb80e_row0_col1, #T_cb80e_row1_col1, #T_cb80e_row2_col0, #T_cb80e_row2_col1, #T_cb80e_row3_col1, #T_cb80e_row4_col1, #T_cb80e_row5_col1, #T_cb80e_row6_col0, #T_cb80e_row6_col1, #T_cb80e_row7_col0, #T_cb80e_row7_col1, #T_cb80e_row8_col1, #T_cb80e_row9_col1, #T_cb80e_row10_col0, #T_cb80e_row10_col1, #T_cb80e_row11_col0, #T_cb80e_row11_col1, #T_cb80e_row12_col0, #T_cb80e_row12_col1, #T_cb80e_row13_col0, #T_cb80e_row13_col1, #T_cb80e_row14_col0, #T_cb80e_row14_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_cb80e_row0_col2, #T_cb80e_row1_col2, #T_cb80e_row2_col2, #T_cb80e_row3_col2, #T_cb80e_row4_col2, #T_cb80e_row5_col2, #T_cb80e_row6_col2, #T_cb80e_row7_col2, #T_cb80e_row8_col2, #T_cb80e_row9_col2, #T_cb80e_row10_col2, #T_cb80e_row11_col2, #T_cb80e_row12_col2, #T_cb80e_row13_col2, #T_cb80e_row14_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_cb80e_row3_col0, #T_cb80e_row4_col0, #T_cb80e_row5_col0 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cb80e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb80e_level0_col0" class="col_heading level0 col0" >13 (0)</th>
#       <th id="T_cb80e_level0_col1" class="col_heading level0 col1" > minutes (1)</th>
#       <th id="T_cb80e_level0_col2" class="col_heading level0 col2" >. (2)</th>
#       <th id="T_cb80e_level0_col3" class="col_heading level0 col3" >perturbed_input</th>
#       <th id="T_cb80e_level0_col4" class="col_heading level0 col4" >perturbed_output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb80e_level0_row0" class="row_heading level0 row0" >The (0)</th>
#       <td id="T_cb80e_row0_col0" class="data row0 col0" >0.294424</td>
#       <td id="T_cb80e_row0_col1" class="data row0 col1" >-0.000000</td>
#       <td id="T_cb80e_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_cb80e_row0_col3" class="data row0 col3" >  clock shows 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_cb80e_row0_col4" class="data row0 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_cb80e_level0_row1" class="row_heading level0 row1" >clock (1)</th>
#       <td id="T_cb80e_row1_col0" class="data row1 col0" >0.294424</td>
#       <td id="T_cb80e_row1_col1" class="data row1 col1" >-0.000000</td>
#       <td id="T_cb80e_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_cb80e_row1_col3" class="data row1 col3" >The  shows 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_cb80e_row1_col4" class="data row1 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_cb80e_level0_row2" class="row_heading level0 row2" >shows (2)</th>
#       <td id="T_cb80e_row2_col0" class="data row2 col0" >-0.000000</td>
#       <td id="T_cb80e_row2_col1" class="data row2 col1" >-0.000000</td>
#       <td id="T_cb80e_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_cb80e_row2_col3" class="data row2 col3" >The clock  9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_cb80e_row2_col4" class="data row2 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_cb80e_level0_row3" class="row_heading level0 row3" >9 (3)</th>
#       <td id="T_cb80e_row3_col0" class="data row3 col0" >0.549087</td>
#       <td id="T_cb80e_row3_col1" class="data row3 col1" >-0.000000</td>
#       <td id="T_cb80e_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_cb80e_row3_col3" class="data row3 col3" >The clock shows    PM. How many minutes 'til 10?</td>
#       <td id="T_cb80e_row3_col4" class="data row3 col4" >There are 120 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_cb80e_level0_row4" class="row_heading level0 row4" >: (4)</th>
#       <td id="T_cb80e_row4_col0" class="data row4 col0" >0.549087</td>
#       <td id="T_cb80e_row4_col1" class="data row4 col1" >-0.000000</td>
#       <td id="T_cb80e_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_cb80e_row4_col3" class="data row4 col3" >The clock shows    PM. How many minutes 'til 10?</td>
#       <td id="T_cb80e_row4_col4" class="data row4 col4" >There are 120 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_cb80e_level0_row5" class="row_heading level0 row5" >47 (5)</th>
#       <td id="T_cb80e_row5_col0" class="data row5 col0" >0.549087</td>
#       <td id="T_cb80e_row5_col1" class="data row5 col1" >-0.000000</td>
#       <td id="T_cb80e_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_cb80e_row5_col3" class="data row5 col3" >The clock shows    PM. How many minutes 'til 10?</td>
#       <td id="T_cb80e_row5_col4" class="data row5 col4" >There are 120 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_cb80e_level0_row6" class="row_heading level0 row6" >PM (6)</th>
#       <td id="T_cb80e_row6_col0" class="data row6 col0" >-0.000000</td>
#       <td id="T_cb80e_row6_col1" class="data row6 col1" >-0.000000</td>
#       <td id="T_cb80e_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_cb80e_row6_col3" class="data row6 col3" >The clock shows 9:47   How many minutes 'til 10?</td>
#       <td id="T_cb80e_row6_col4" class="data row6 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_cb80e_level0_row7" class="row_heading level0 row7" >. (7)</th>
#       <td id="T_cb80e_row7_col0" class="data row7 col0" >-0.000000</td>
#       <td id="T_cb80e_row7_col1" class="data row7 col1" >-0.000000</td>
#       <td id="T_cb80e_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_cb80e_row7_col3" class="data row7 col3" >The clock shows 9:47   How many minutes 'til 10?</td>
#       <td id="T_cb80e_row7_col4" class="data row7 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_cb80e_level0_row8" class="row_heading level0 row8" >How (8)</th>
#       <td id="T_cb80e_row8_col0" class="data row8 col0" >0.294424</td>
#       <td id="T_cb80e_row8_col1" class="data row8 col1" >-0.000000</td>
#       <td id="T_cb80e_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_cb80e_row8_col3" class="data row8 col3" >The clock shows 9:47 PM.  many minutes 'til 10?</td>
#       <td id="T_cb80e_row8_col4" class="data row8 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_cb80e_level0_row9" class="row_heading level0 row9" >many (9)</th>
#       <td id="T_cb80e_row9_col0" class="data row9 col0" >0.294424</td>
#       <td id="T_cb80e_row9_col1" class="data row9 col1" >-0.000000</td>
#       <td id="T_cb80e_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_cb80e_row9_col3" class="data row9 col3" >The clock shows 9:47 PM. How  minutes 'til 10?</td>
#       <td id="T_cb80e_row9_col4" class="data row9 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_cb80e_level0_row10" class="row_heading level0 row10" >minutes (10)</th>
#       <td id="T_cb80e_row10_col0" class="data row10 col0" >-0.000000</td>
#       <td id="T_cb80e_row10_col1" class="data row10 col1" >-0.000000</td>
#       <td id="T_cb80e_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_cb80e_row10_col3" class="data row10 col3" >The clock shows 9:47 PM. How many  'til 10?</td>
#       <td id="T_cb80e_row10_col4" class="data row10 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_cb80e_level0_row11" class="row_heading level0 row11" >' (11)</th>
#       <td id="T_cb80e_row11_col0" class="data row11 col0" >-0.000000</td>
#       <td id="T_cb80e_row11_col1" class="data row11 col1" >-0.000000</td>
#       <td id="T_cb80e_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_cb80e_row11_col3" class="data row11 col3" >The clock shows 9:47 PM. How many minutes   10?</td>
#       <td id="T_cb80e_row11_col4" class="data row11 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_cb80e_level0_row12" class="row_heading level0 row12" >til (12)</th>
#       <td id="T_cb80e_row12_col0" class="data ro
# Attribution matrix for experiment 1
# Attribution Strategy: prob_diff
# Perturbation strategy: fixed:
# Input Tokens (Rows) vs. Output Tokens (Columns)
# <style type="text/css">
# #T_12173_row0_col0, #T_12173_row1_col0, #T_12173_row8_col0, #T_12173_row9_col0 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_12173_row0_col1, #T_12173_row1_col1, #T_12173_row2_col1, #T_12173_row6_col1, #T_12173_row7_col1, #T_12173_row8_col1, #T_12173_row9_col1, #T_12173_row10_col1, #T_12173_row11_col1, #T_12173_row12_col1 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_12173_row0_col2, #T_12173_row1_col2, #T_12173_row9_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_12173_row2_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_12173_row2_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_12173_row3_col0, #T_12173_row4_col0, #T_12173_row5_col0 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_12173_row3_col1, #T_12173_row4_col1, #T_12173_row5_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_12173_row3_col2, #T_12173_row4_col2, #T_12173_row5_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_12173_row6_col0, #T_12173_row7_col0 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_12173_row6_col2, #T_12173_row7_col2 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_12173_row8_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_12173_row10_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_12173_row10_col2 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_12173_row11_col0, #T_12173_row12_col0 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_12173_row11_col2, #T_12173_row12_col2 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_12173_row13_col0, #T_12173_row14_col0 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_12173_row13_col1, #T_12173_row14_col1 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_12173_row13_col2, #T_12173_row14_col2 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# </style>
# <table id="T_12173">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12173_level0_col0" class="col_heading level0 col0" >13 (0)</th>
#       <th id="T_12173_level0_col1" class="col_heading level0 col1" > minutes (1)</th>
#       <th id="T_12173_level0_col2" class="col_heading level0 col2" >. (2)</th>
#       <th id="T_12173_level0_col3" class="col_heading level0 col3" >perturbed_input</th>
#       <th id="T_12173_level0_col4" class="col_heading level0 col4" >perturbed_output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12173_level0_row0" class="row_heading level0 row0" >The (0)</th>
#       <td id="T_12173_row0_col0" class="data row0 col0" >-0.295916</td>
#       <td id="T_12173_row0_col1" class="data row0 col1" >0.000114</td>
#       <td id="T_12173_row0_col2" class="data row0 col2" >-0.345493</td>
#       <td id="T_12173_row0_col3" class="data row0 col3" >  clock shows 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_12173_row0_col4" class="data row0 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_12173_level0_row1" class="row_heading level0 row1" >clock (1)</th>
#       <td id="T_12173_row1_col0" class="data row1 col0" >-0.295896</td>
#       <td id="T_12173_row1_col1" class="data row1 col1" >0.000242</td>
#       <td id="T_12173_row1_col2" class="data row1 col2" >-0.351146</td>
#       <td id="T_12173_row1_col3" class="data row1 col3" >The  shows 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_12173_row1_col4" class="data row1 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_12173_level0_row2" class="row_heading level0 row2" >shows (2)</th>
#       <td id="T_12173_row2_col0" class="data row2 col0" >0.100526</td>
#       <td id="T_12173_row2_col1" class="data row2 col1" >0.000007</td>
#       <td id="T_12173_row2_col2" class="data row2 col2" >0.116491</td>
#       <td id="T_12173_row2_col3" class="data row2 col3" >The clock  9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_12173_row2_col4" class="data row2 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_12173_level0_row3" class="row_heading level0 row3" >9 (3)</th>
#       <td id="T_12173_row3_col0" class="data row3 col0" >0.704032</td>
#       <td id="T_12173_row3_col1" class="data row3 col1" >-0.000059</td>
#       <td id="T_12173_row3_col2" class="data row3 col2" >-0.352841</td>
#       <td id="T_12173_row3_col3" class="data row3 col3" >The clock shows    PM. How many minutes 'til 10?</td>
#       <td id="T_12173_row3_col4" class="data row3 col4" >There are 120 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_12173_level0_row4" class="row_heading level0 row4" >: (4)</th>
#       <td id="T_12173_row4_col0" class="data row4 col0" >0.704032</td>
#       <td id="T_12173_row4_col1" class="data row4 col1" >-0.000059</td>
#       <td id="T_12173_row4_col2" class="data row4 col2" >-0.352841</td>
#       <td id="T_12173_row4_col3" class="data row4 col3" >The clock shows    PM. How many minutes 'til 10?</td>
#       <td id="T_12173_row4_col4" class="data row4 col4" >There are 120 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_12173_level0_row5" class="row_heading level0 row5" >47 (5)</th>
#       <td id="T_12173_row5_col0" class="data row5 col0" >0.704032</td>
#       <td id="T_12173_row5_col1" class="data row5 col1" >-0.000059</td>
#       <td id="T_12173_row5_col2" class="data row5 col2" >-0.352841</td>
#       <td id="T_12173_row5_col3" class="data row5 col3" >The clock shows    PM. How many minutes 'til 10?</td>
#       <td id="T_12173_row5_col4" class="data row5 col4" >There are 120 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_12173_level0_row6" class="row_heading level0 row6" >PM (6)</th>
#       <td id="T_12173_row6_col0" class="data row6 col0" >0.028417</td>
#       <td id="T_12173_row6_col1" class="data row6 col1" >0.000034</td>
#       <td id="T_12173_row6_col2" class="data row6 col2" >0.170953</td>
#       <td id="T_12173_row6_col3" class="data row6 col3" >The clock shows 9:47   How many minutes 'til 10?</td>
#       <td id="T_12173_row6_col4" class="data row6 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_12173_level0_row7" class="row_heading level0 row7" >. (7)</th>
#       <td id="T_12173_row7_col0" class="data row7 col0" >0.028417</td>
#       <td id="T_12173_row7_col1" class="data row7 col1" >0.000034</td>
#       <td id="T_12173_row7_col2" class="data row7 col2" >0.170953</td>
#       <td id="T_12173_row7_col3" class="data row7 col3" >The clock shows 9:47   How many minutes 'til 10?</td>
#       <td id="T_12173_row7_col4" class="data row7 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_12173_level0_row8" class="row_heading level0 row8" >How (8)</th>
#       <td id="T_12173_row8_col0" class="data row8 col0" >-0.295946</td>
#       <td id="T_12173_row8_col1" class="data row8 col1" >0.000343</td>
#       <td id="T_12173_row8_col2" class="data row8 col2" >-0.327357</td>
#       <td id="T_12173_row8_col3" class="data row8 col3" >The clock shows 9:47 PM.  many minutes 'til 10?</td>
#       <td id="T_12173_row8_col4" class="data row8 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_12173_level0_row9" class="row_heading level0 row9" >many (9)</th>
#       <td id="T_12173_row9_col0" class="data row9 col0" >-0.295846</td>
#       <td id="T_12173_row9_col1" class="data row9 col1" >0.000039</td>
#       <td id="T_12173_row9_col2" class="data row9 col2" >-0.349091</td>
#       <td id="T_12173_row9_col3" class="data row9 col3" >The clock shows 9:47 PM. How  minutes 'til 10?</td>
#       <td id="T_12173_row9_col4" class="data row9 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_12173_level0_row10" class="row_heading level0 row10" >minutes (10)</th>
#       <td id="T_12173_row10_col0" class="data row10 col0" >0.209895</td>
#       <td id="T_12173_row10_col1" class="data row10 col1" >0.002099</td>
#       <td id="T_12173_row10_col2" class="data row10 col2" >0.152099</td>
#       <td id="T_12173_row10_col3" class="data row10 col3" >The clock shows 9:47 PM. How many  'til 10?</td>
#       <td id="T_12173_row10_col4" clas

# %%
logger.df_experiments
# Out:
#    exp_id                                     original_input original_output  \
# 0       1  The clock shows 9:47 PM. How many minutes 'til...     13 minutes.
# 1       2  The clock shows 9:47 PM. How many minutes 'til...     13 minutes.
# 2       3  The clock shows 9:47 PM. How many minutes 'til...     13 minutes.
#
#   perturbation_strategy  perturb_word_wise   duration
# 0                 fixed               True   7.927439
# 1     nth_nearest (n=0)               True    9.00721
# 2    nth_nearest (n=-1)               True  10.326304
