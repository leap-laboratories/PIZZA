# %%
# Re-import modified modules without restarting the server
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
import warnings

notebook_path = os.path.abspath(get_ipython().starting_dir)
parent_path = os.path.dirname(notebook_path)

sys.path.append(parent_path)
warnings.simplefilter("ignore")

# %%
from attribution.api_attribution import OpenAIAttributor
from attribution.experiment_logger import ExperimentLogger
from attribution.token_perturbation import (
    FixedPerturbationStrategy,
    NthNearestPerturbationStrategy,
)

# %%
attributor = OpenAIAttributor()
logger = ExperimentLogger()
await attributor.iterative_perturbation(
    "The clock shows 9:47 PM. How many minutes 'til 10?",
    perturbation_strategy=NthNearestPerturbationStrategy(n=-1),
    attribution_strategies=["cosine"],
    logger=logger,
    unit_definition="word",
)
display(logger.df_experiments)
logger.print_total_attribution()
logger.print_attribution_matrix(exp_id=1)
# Out:
#    exp_id                                     original_input original_output  \
# 0       1  The clock shows 9:47 PM. How many minutes 'til...     13 minutes.
#
#   perturbation_strategy unit_definition  duration num_llm_calls
# 0    nth_nearest (n=-1)            word  4.205097            11
# <style type="text/css">
# #T_6e56f_row0_col0, #T_6e56f_row0_col1, #T_6e56f_row0_col2, #T_6e56f_row0_col3, #T_6e56f_row0_col4, #T_6e56f_row0_col5, #T_6e56f_row0_col6, #T_6e56f_row0_col7, #T_6e56f_row0_col8, #T_6e56f_row0_col9, #T_6e56f_row0_col10, #T_6e56f_row0_col11, #T_6e56f_row0_col12, #T_6e56f_row0_col13 {
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_6e56f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e56f_level0_col0" class="col_heading level0 col0" >exp_id</th>
#       <th id="T_6e56f_level0_col1" class="col_heading level0 col1" >attribution_strategy</th>
#       <th id="T_6e56f_level0_col2" class="col_heading level0 col2" >perturbation_strategy</th>
#       <th id="T_6e56f_level0_col3" class="col_heading level0 col3" >unit_definition</th>
#       <th id="T_6e56f_level0_col4" class="col_heading level0 col4" >token_1</th>
#       <th id="T_6e56f_level0_col5" class="col_heading level0 col5" >token_2</th>
#       <th id="T_6e56f_level0_col6" class="col_heading level0 col6" >token_3</th>
#       <th id="T_6e56f_level0_col7" class="col_heading level0 col7" >token_4</th>
#       <th id="T_6e56f_level0_col8" class="col_heading level0 col8" >token_5</th>
#       <th id="T_6e56f_level0_col9" class="col_heading level0 col9" >token_6</th>
#       <th id="T_6e56f_level0_col10" class="col_heading level0 col10" >token_7</th>
#       <th id="T_6e56f_level0_col11" class="col_heading level0 col11" >token_8</th>
#       <th id="T_6e56f_level0_col12" class="col_heading level0 col12" >token_9</th>
#       <th id="T_6e56f_level0_col13" class="col_heading level0 col13" >token_10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e56f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e56f_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_6e56f_row0_col1" class="data row0 col1" >cosine</td>
#       <td id="T_6e56f_row0_col2" class="data row0 col2" >nth_nearest (n=-1)</td>
#       <td id="T_6e56f_row0_col3" class="data row0 col3" >word</td>
#       <td id="T_6e56f_row0_col4" class="data row0 col4" >The
# -0.00</td>
#       <td id="T_6e56f_row0_col5" class="data row0 col5" > clock
# 0.10</td>
#       <td id="T_6e56f_row0_col6" class="data row0 col6" > shows
# 0.10</td>
#       <td id="T_6e56f_row0_col7" class="data row0 col7" > 9:47
# 0.15</td>
#       <td id="T_6e56f_row0_col8" class="data row0 col8" > PM.
# 0.10</td>
#       <td id="T_6e56f_row0_col9" class="data row0 col9" > How
# 0.10</td>
#       <td id="T_6e56f_row0_col10" class="data row0 col10" > many
# 0.10</td>
#       <td id="T_6e56f_row0_col11" class="data row0 col11" > minutes
# 0.10</td>
#       <td id="T_6e56f_row0_col12" class="data row0 col12" > 'til
# 0.23</td>
#       <td id="T_6e56f_row0_col13" class="data row0 col13" > 10?
# 0.23</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ce6dc_row0_col0, #T_ce6dc_row0_col1, #T_ce6dc_row1_col1, #T_ce6dc_row2_col1, #T_ce6dc_row3_col1, #T_ce6dc_row4_col1, #T_ce6dc_row5_col1, #T_ce6dc_row6_col1, #T_ce6dc_row7_col1, #T_ce6dc_row8_col0, #T_ce6dc_row8_col1, #T_ce6dc_row9_col0, #T_ce6dc_row9_col1 {
#   background-color: #fdfdff;
#   color: #000000;
#   white-space: pre-wrap;
# }
# #T_ce6dc_row0_col2, #T_ce6dc_row1_col2, #T_ce6dc_row2_col2, #T_ce6dc_row3_col2, #T_ce6dc_row4_col2, #T_ce6dc_row5_col2, #T_ce6dc_row6_col2, #T_ce6dc_row7_col2 {
#   background-color: #fffdfd;
#   color: #000000;
#   white-space: pre-wrap;
# }
# #T_ce6dc_row1_col0, #T_ce6dc_row2_col0, #T_ce6dc_row4_col0, #T_ce6dc_row5_col0, #T_ce6dc_row6_col0, #T_ce6dc_row7_col0 {
#   background-color: #ff6969;
#   color: #f1f1f1;
#   white-space: pre-wrap;
# }
# #T_ce6dc_row3_col0 {
#   background-color: #ff1919;
#   color: #f1f1f1;
#   white-space: pre-wrap;
# }
# #T_ce6dc_row8_col2, #T_ce6dc_row9_col2 {
#   background-color: #ce0000;
#   color: #f1f1f1;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_ce6dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce6dc_level0_col0" class="col_heading level0 col0" >13 (0)</th>
#       <th id="T_ce6dc_level0_col1" class="col_heading level0 col1" > minutes (1)</th>
#       <th id="T_ce6dc_level0_col2" class="col_heading level0 col2" >. (2)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce6dc_level0_row0" class="row_heading level0 row0" >The (0)</th>
#       <td id="T_ce6dc_row0_col0" class="data row0 col0" >-0.000000</td>
#       <td id="T_ce6dc_row0_col1" class="data row0 col1" >-0.000000</td>
#       <td id="T_ce6dc_row0_col2" class="data row0 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ce6dc_level0_row1" class="row_heading level0 row1" > clock (1)</th>
#       <td id="T_ce6dc_row1_col0" class="data row1 col0" >0.294424</td>
#       <td id="T_ce6dc_row1_col1" class="data row1 col1" >-0.000000</td>
#       <td id="T_ce6dc_row1_col2" class="data row1 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ce6dc_level0_row2" class="row_heading level0 row2" > shows (2)</th>
#       <td id="T_ce6dc_row2_col0" class="data row2 col0" >0.294424</td>
#       <td id="T_ce6dc_row2_col1" class="data row2 col1" >-0.000000</td>
#       <td id="T_ce6dc_row2_col2" class="data row2 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ce6dc_level0_row3" class="row_heading level0 row3" > 9:47 (3)</th>
#       <td id="T_ce6dc_row3_col0" class="data row3 col0" >0.446213</td>
#       <td id="T_ce6dc_row3_col1" class="data row3 col1" >-0.000000</td>
#       <td id="T_ce6dc_row3_col2" class="data row3 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ce6dc_level0_row4" class="row_heading level0 row4" > PM. (4)</th>
#       <td id="T_ce6dc_row4_col0" class="data row4 col0" >0.294424</td>
#       <td id="T_ce6dc_row4_col1" class="data row4 col1" >-0.000000</td>
#       <td id="T_ce6dc_row4_col2" class="data row4 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ce6dc_level0_row5" class="row_heading level0 row5" > How (5)</th>
#       <td id="T_ce6dc_row5_col0" class="data row5 col0" >0.294424</td>
#       <td id="T_ce6dc_row5_col1" class="data row5 col1" >-0.000000</td>
#       <td id="T_ce6dc_row5_col2" class="data row5 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ce6dc_level0_row6" class="row_heading level0 row6" > many (6)</th>
#       <td id="T_ce6dc_row6_col0" class="data row6 col0" >0.294424</td>
#       <td id="T_ce6dc_row6_col1" class="data row6 col1" >-0.000000</td>
#       <td id="T_ce6dc_row6_col2" class="data row6 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ce6dc_level0_row7" class="row_heading level0 row7" > minutes (7)</th>
#       <td id="T_ce6dc_row7_col0" class="data row7 col0" >0.294424</td>
#       <td id="T_ce6dc_row7_col1" class="data row7 col1" >-0.000000</td>
#       <td id="T_ce6dc_row7_col2" class="data row7 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ce6dc_level0_row8" class="row_heading level0 row8" > 'til (8)</th>
#       <td id="T_ce6dc_row8_col0" class="data row8 col0" >-0.000000</td>
#       <td id="T_ce6dc_row8_col1" class="data row8 col1" >-0.000000</td>
#       <td id="T_ce6dc_row8_col2" class="data row8 col2" >0.690817</td>
#     </tr>
#     <tr>
#       <th id="T_ce6dc_level0_row9" class="row_heading level0 row9" > 10? (9)</th>
#       <td id="T_ce6dc_row9_col0" class="data row9 col0" >-0.000000</td>
#       <td id="T_ce6dc_row9_col1" class="data row9 col1" >-0.000000</td>
#       <td id="T_ce6dc_row9_col2" class="data row9 col2" >0.690817</td>
#     </tr>
#   </tbody>
# </table>

# %%
logger.print_attribution_matrix(exp_id=1, show_debug_cols=True)
# Out:
# <style type="text/css">
# #T_f168f_row0_col0, #T_f168f_row0_col1, #T_f168f_row1_col1, #T_f168f_row2_col1, #T_f168f_row3_col1, #T_f168f_row4_col1, #T_f168f_row5_col1, #T_f168f_row6_col1, #T_f168f_row7_col1, #T_f168f_row8_col0, #T_f168f_row8_col1, #T_f168f_row9_col0, #T_f168f_row9_col1 {
#   background-color: #fdfdff;
#   color: #000000;
#   white-space: pre-wrap;
# }
# #T_f168f_row0_col2, #T_f168f_row1_col2, #T_f168f_row2_col2, #T_f168f_row3_col2, #T_f168f_row4_col2, #T_f168f_row5_col2, #T_f168f_row6_col2, #T_f168f_row7_col2 {
#   background-color: #fffdfd;
#   color: #000000;
#   white-space: pre-wrap;
# }
# #T_f168f_row0_col3, #T_f168f_row0_col4, #T_f168f_row1_col3, #T_f168f_row1_col4, #T_f168f_row2_col3, #T_f168f_row2_col4, #T_f168f_row3_col3, #T_f168f_row3_col4, #T_f168f_row4_col3, #T_f168f_row4_col4, #T_f168f_row5_col3, #T_f168f_row5_col4, #T_f168f_row6_col3, #T_f168f_row6_col4, #T_f168f_row7_col3, #T_f168f_row7_col4, #T_f168f_row8_col3, #T_f168f_row8_col4, #T_f168f_row9_col3, #T_f168f_row9_col4 {
#   white-space: pre-wrap;
# }
# #T_f168f_row1_col0, #T_f168f_row2_col0, #T_f168f_row4_col0, #T_f168f_row5_col0, #T_f168f_row6_col0, #T_f168f_row7_col0 {
#   background-color: #ff6969;
#   color: #f1f1f1;
#   white-space: pre-wrap;
# }
# #T_f168f_row3_col0 {
#   background-color: #ff1919;
#   color: #f1f1f1;
#   white-space: pre-wrap;
# }
# #T_f168f_row8_col2, #T_f168f_row9_col2 {
#   background-color: #ce0000;
#   color: #f1f1f1;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_f168f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f168f_level0_col0" class="col_heading level0 col0" >13 (0)</th>
#       <th id="T_f168f_level0_col1" class="col_heading level0 col1" > minutes (1)</th>
#       <th id="T_f168f_level0_col2" class="col_heading level0 col2" >. (2)</th>
#       <th id="T_f168f_level0_col3" class="col_heading level0 col3" >perturbed_input</th>
#       <th id="T_f168f_level0_col4" class="col_heading level0 col4" >perturbed_output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f168f_level0_row0" class="row_heading level0 row0" >The (0)</th>
#       <td id="T_f168f_row0_col0" class="data row0 col0" >-0.000000</td>
#       <td id="T_f168f_row0_col1" class="data row0 col1" >-0.000000</td>
#       <td id="T_f168f_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_f168f_row0_col3" class="data row0 col3" >Streamer clock shows 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_f168f_row0_col4" class="data row0 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_f168f_level0_row1" class="row_heading level0 row1" > clock (1)</th>
#       <td id="T_f168f_row1_col0" class="data row1 col0" >0.294424</td>
#       <td id="T_f168f_row1_col1" class="data row1 col1" >-0.000000</td>
#       <td id="T_f168f_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_f168f_row1_col3" class="data row1 col3" >The ur shows 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_f168f_row1_col4" class="data row1 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_f168f_level0_row2" class="row_heading level0 row2" > shows (2)</th>
#       <td id="T_f168f_row2_col0" class="data row2 col0" >0.294424</td>
#       <td id="T_f168f_row2_col1" class="data row2 col1" >-0.000000</td>
#       <td id="T_f168f_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_f168f_row2_col3" class="data row2 col3" >The clock etooth 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_f168f_row2_col4" class="data row2 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_f168f_level0_row3" class="row_heading level0 row3" > 9:47 (3)</th>
#       <td id="T_f168f_row3_col0" class="data row3 col0" >0.446213</td>
#       <td id="T_f168f_row3_col1" class="data row3 col1" >-0.000000</td>
#       <td id="T_f168f_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_f168f_row3_col3" class="data row3 col3" >The clock shows DERRSPONSOREDric PM. How many minutes 'til 10?</td>
#       <td id="T_f168f_row3_col4" class="data row3 col4" >There are 60 minutes in an hour, so from 9:00 PM to 10:00 PM, there are 60 minutes. Since the current time is 9:54 PM, there are 6 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_f168f_level0_row4" class="row_heading level0 row4" > PM. (4)</th>
#       <td id="T_f168f_row4_col0" class="data row4 col0" >0.294424</td>
#       <td id="T_f168f_row4_col1" class="data row4 col1" >-0.000000</td>
#       <td id="T_f168f_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_f168f_row4_col3" class="data row4 col3" >The clock shows 9:47 Tusastical How many minutes 'til 10?</td>
#       <td id="T_f168f_row4_col4" class="data row4 col4" >There are 13 minutes until 10:00.</td>
#     </tr>
#     <tr>
#       <th id="T_f168f_level0_row5" class="row_heading level0 row5" > How (5)</th>
#       <td id="T_f168f_row5_col0" class="data row5 col0" >0.294424</td>
#       <td id="T_f168f_row5_col1" class="data row5 col1" >-0.000000</td>
#       <td id="T_f168f_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_f168f_row5_col3" class="data row5 col3" >The clock shows 9:47 PM. erate many minutes 'til 10?</td>
#       <td id="T_f168f_row5_col4" class="data row5 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_f168f_level0_row6" class="row_heading level0 row6" > many (6)</th>
#       <td id="T_f168f_row6_col0" class="data row6 col0" >0.294424</td>
#       <td id="T_f168f_row6_col1" class="data row6 col1" >-0.000000</td>
#       <td id="T_f168f_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_f168f_row6_col3" class="data row6 col3" >The clock shows 9:47 PM. How izu minutes 'til 10?</td>
#       <td id="T_f168f_row6_col4" class="data row6 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_f168f_level0_row7" class="row_heading level0 row7" > minutes (7)</th>
#       <td id="T_f168f_row7_col0" class="data row7 col0" >0.294424</td>
#       <td id="T_f168f_row7_col1" class="data row7 col1" >-0.000000</td>
#       <td id="T_f168f_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_f168f_row7_col3" class="data row7 col3" >The clock shows 9:47 PM. How many tain 'til 10?</td>
#       <td id="T_f168f_row7_col4" class="data row7 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_f168f_level0_row8" class="row_heading level0 row8" > 'til (8)</th>
#       <td id="T_f168f_row8_col0" class="data row8 col0" >-0.000000</td>
#       <td id="T_f168f_row8_col1" class="data row8 col1" >-0.000000</td>
#       <td id="T_f168f_row8_col2" class="data row8 col2" >0.690817</td>
#       <td id="T_f168f_row8_col3" class="data row8 col3" >The clock shows 9:47 PM. How many minutes isine the 10?</td>
#       <td id="T_f168f_row8_col4" class="data row8 col4" >13 minutes</td>
#     </tr>
#     <tr>
#       <th id="T_f168f_level0_row9" class="row_heading level0 row9" > 10? (9)</th>
#       <td id="T_f168f_row9_col0" class="data row9 col0" >-0.000000</td>
#       <td id="T_f168f_row9_col1" class="data row9 col1" >-0.000000</td>
#       <td id="T_f168f_row9_col2" class="data row9 col2" >0.690817</td>
#       <td id="T_f168f_row9_col3" class="data row9 col3" >The clock shows 9:47 PM. How many minutes 'til DERR prov</td>
#       <td id="T_f168f_row9_col4" class="data row9 col4" >13 minutes</td>
#     </tr>
#   </tbody>
# </table>

# %%
attributor = OpenAIAttributor()

input_texts = ["The clock shows 9:47 PM. How many minutes 'til 10?"]

perturbation_strategies = [
    FixedPerturbationStrategy(),
    NthNearestPerturbationStrategy(n=0),
    NthNearestPerturbationStrategy(n=-1),
    # (PerturbationStrategy.NTH_NEAREST, {"n": 10}),
]

# Initialize the logger
logger = ExperimentLogger()

# Perform the experiment
for input_text in input_texts:
    for perturbation_strategy in perturbation_strategies:
        await attributor.iterative_perturbation(
            input_text,
            perturbation_strategy=perturbation_strategy,
            attribution_strategies=["cosine", "prob_diff"],
            logger=logger,
            unit_definition="word",
        )

# Display the results
display(logger.df_experiments)
logger.print_total_attribution()
# Out:
#    exp_id                                     original_input original_output  \
# 0       1  The clock shows 9:47 PM. How many minutes 'til...     13 minutes.
# 1       2  The clock shows 9:47 PM. How many minutes 'til...     13 minutes.
# 2       3  The clock shows 9:47 PM. How many minutes 'til...     13 minutes.
#
#   perturbation_strategy unit_definition  duration num_llm_calls
# 0                 fixed            word  1.174003            11
# 1     nth_nearest (n=0)            word   3.70429            11
# 2    nth_nearest (n=-1)            word  4.377963            11
# <style type="text/css">
# #T_db325_row0_col0, #T_db325_row0_col1, #T_db325_row0_col2, #T_db325_row0_col3, #T_db325_row0_col4, #T_db325_row0_col5, #T_db325_row0_col6, #T_db325_row0_col7, #T_db325_row0_col8, #T_db325_row0_col9, #T_db325_row0_col10, #T_db325_row0_col11, #T_db325_row0_col12, #T_db325_row0_col13, #T_db325_row1_col0, #T_db325_row1_col1, #T_db325_row1_col2, #T_db325_row1_col3, #T_db325_row1_col4, #T_db325_row1_col5, #T_db325_row1_col6, #T_db325_row1_col7, #T_db325_row1_col8, #T_db325_row1_col9, #T_db325_row1_col10, #T_db325_row1_col11, #T_db325_row1_col12, #T_db325_row1_col13, #T_db325_row2_col0, #T_db325_row2_col1, #T_db325_row2_col2, #T_db325_row2_col3, #T_db325_row2_col4, #T_db325_row2_col5, #T_db325_row2_col6, #T_db325_row2_col7, #T_db325_row2_col8, #T_db325_row2_col9, #T_db325_row2_col10, #T_db325_row2_col11, #T_db325_row2_col12, #T_db325_row2_col13, #T_db325_row3_col0, #T_db325_row3_col1, #T_db325_row3_col2, #T_db325_row3_col3, #T_db325_row3_col4, #T_db325_row3_col5, #T_db325_row3_col6, #T_db325_row3_col7, #T_db325_row3_col8, #T_db325_row3_col9, #T_db325_row3_col10, #T_db325_row3_col11, #T_db325_row3_col12, #T_db325_row3_col13, #T_db325_row4_col0, #T_db325_row4_col1, #T_db325_row4_col2, #T_db325_row4_col3, #T_db325_row4_col4, #T_db325_row4_col5, #T_db325_row4_col6, #T_db325_row4_col7, #T_db325_row4_col8, #T_db325_row4_col9, #T_db325_row4_col10, #T_db325_row4_col11, #T_db325_row4_col12, #T_db325_row4_col13, #T_db325_row5_col0, #T_db325_row5_col1, #T_db325_row5_col2, #T_db325_row5_col3, #T_db325_row5_col4, #T_db325_row5_col5, #T_db325_row5_col6, #T_db325_row5_col7, #T_db325_row5_col8, #T_db325_row5_col9, #T_db325_row5_col10, #T_db325_row5_col11, #T_db325_row5_col12, #T_db325_row5_col13 {
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_db325">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db325_level0_col0" class="col_heading level0 col0" >exp_id</th>
#       <th id="T_db325_level0_col1" class="col_heading level0 col1" >attribution_strategy</th>
#       <th id="T_db325_level0_col2" class="col_heading level0 col2" >perturbation_strategy</th>
#       <th id="T_db325_level0_col3" class="col_heading level0 col3" >unit_definition</th>
#       <th id="T_db325_level0_col4" class="col_heading level0 col4" >token_1</th>
#       <th id="T_db325_level0_col5" class="col_heading level0 col5" >token_2</th>
#       <th id="T_db325_level0_col6" class="col_heading level0 col6" >token_3</th>
#       <th id="T_db325_level0_col7" class="col_heading level0 col7" >token_4</th>
#       <th id="T_db325_level0_col8" class="col_heading level0 col8" >token_5</th>
#       <th id="T_db325_level0_col9" class="col_heading level0 col9" >token_6</th>
#       <th id="T_db325_level0_col10" class="col_heading level0 col10" >token_7</th>
#       <th id="T_db325_level0_col11" class="col_heading level0 col11" >token_8</th>
#       <th id="T_db325_level0_col12" class="col_heading level0 col12" >token_9</th>
#       <th id="T_db325_level0_col13" class="col_heading level0 col13" >token_10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db325_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db325_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_db325_row0_col1" class="data row0 col1" >cosine</td>
#       <td id="T_db325_row0_col2" class="data row0 col2" >fixed</td>
#       <td id="T_db325_row0_col3" class="data row0 col3" >word</td>
#       <td id="T_db325_row0_col4" class="data row0 col4" >The
# -0.00</td>
#       <td id="T_db325_row0_col5" class="data row0 col5" > clock
# -0.00</td>
#       <td id="T_db325_row0_col6" class="data row0 col6" > shows
# -0.00</td>
#       <td id="T_db325_row0_col7" class="data row0 col7" > 9:47
# 0.18</td>
#       <td id="T_db325_row0_col8" class="data row0 col8" > PM.
# -0.00</td>
#       <td id="T_db325_row0_col9" class="data row0 col9" > How
# 0.10</td>
#       <td id="T_db325_row0_col10" class="data row0 col10" > many
# -0.00</td>
#       <td id="T_db325_row0_col11" class="data row0 col11" > minutes
# -0.00</td>
#       <td id="T_db325_row0_col12" class="data row0 col12" > 'til
# -0.00</td>
#       <td id="T_db325_row0_col13" class="data row0 col13" > 10?
# -0.00</td>
#     </tr>
#     <tr>
#       <th id="T_db325_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_db325_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_db325_row1_col1" class="data row1 col1" >prob_diff</td>
#       <td id="T_db325_row1_col2" class="data row1 col2" >fixed</td>
#       <td id="T_db325_row1_col3" class="data row1 col3" >word</td>
#       <td id="T_db325_row1_col4" class="data row1 col4" >The
# 0.06</td>
#       <td id="T_db325_row1_col5" class="data row1 col5" > clock
# 0.09</td>
#       <td id="T_db325_row1_col6" class="data row1 col6" > shows
# 0.06</td>
#       <td id="T_db325_row1_col7" class="data row1 col7" > 9:47
# 0.14</td>
#       <td id="T_db325_row1_col8" class="data row1 col8" > PM.
# 0.08</td>
#       <td id="T_db325_row1_col9" class="data row1 col9" > How
# -0.19</td>
#       <td id="T_db325_row1_col10" class="data row1 col10" > many
# 0.12</td>
#       <td id="T_db325_row1_col11" class="data row1 col11" > minutes
# 0.02</td>
#       <td id="T_db325_row1_col12" class="data row1 col12" > 'til
# 0.08</td>
#       <td id="T_db325_row1_col13" class="data row1 col13" > 10?
# 0.03</td>
#     </tr>
#     <tr>
#       <th id="T_db325_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_db325_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_db325_row2_col1" class="data row2 col1" >cosine</td>
#       <td id="T_db325_row2_col2" class="data row2 col2" >nth_nearest (n=0)</td>
#       <td id="T_db325_row2_col3" class="data row2 col3" >word</td>
#       <td id="T_db325_row2_col4" class="data row2 col4" >The
# -0.00</td>
#       <td id="T_db325_row2_col5" class="data row2 col5" > clock
# -0.00</td>
#       <td id="T_db325_row2_col6" class="data row2 col6" > shows
# -0.00</td>
#       <td id="T_db325_row2_col7" class="data row2 col7" > 9:47
# 0.10</td>
#       <td id="T_db325_row2_col8" class="data row2 col8" > PM.
# -0.00</td>
#       <td id="T_db325_row2_col9" class="data row2 col9" > How
# -0.00</td>
#       <td id="T_db325_row2_col10" class="data row2 col10" > many
# -0.00</td>
#       <td id="T_db325_row2_col11" class="data row2 col11" > minutes
# -0.00</td>
#       <td id="T_db325_row2_col12" class="data row2 col12" > 'til
# 0.10</td>
#       <td id="T_db325_row2_col13" class="data row2 col13" > 10?
# -0.00</td>
#     </tr>
#     <tr>
#       <th id="T_db325_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_db325_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_db325_row3_col1" class="data row3 col1" >prob_diff</td>
#       <td id="T_db325_row3_col2" class="data row3 col2" >nth_nearest (n=0)</td>
#       <td id="T_db325_row3_col3" class="data row3 col3" >word</td>
#       <td id="T_db325_row3_col4" class="data row3 col4" >The
# -0.02</td>
#       <td id="T_db325_row3_col5" class="data row3 col5" > clock
# -0.00</td>
#       <td id="T_db325_row3_col6" class="data row3 col6" > shows
# -0.00</td>
#       <td id="T_db325_row3_col7" class="data row3 col7" > 9:47
# -0.21</td>
#       <td id="T_db325_row3_col8" class="data row3 col8" > PM.
# 0.01</td>
#       <td id="T_db325_row3_col9" class="data row3 col9" > How
# -0.01</td>
#       <td id="T_db325_row3_col10" class="data row3 col10" > many
# -0.02</td>
#       <td id="T_db325_row3_col11" class="data row3 col11" > minutes
# -0.02</td>
#       <td id="T_db325_row3_col12" class="data row3 col12" > 'til
# -0.22</td>
#       <td id="T_db325_row3_col13" class="data row3 col13" > 10?
# 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_db325_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_db325_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_db325_row4_col1" class="data row4 col1" >cosine</td>
#       <td id="T_db325_row4_col2" class="data row4 col2" >nth_nearest (n=-1)</td>
#       <td id="T_db325_row4_col3" class="data row4 col3" >word</td>
#       <td id="T_db325_row4_col4" class="data row4 col4" >The
# -0.00</td>
#       <td id="T_db325_row4_col5" class="data row4 c

# %%
logger.print_attribution_matrix(exp_id=1, show_debug_cols=True)
# Out:
# <style type="text/css">
# #T_415c5_row0_col0, #T_415c5_row0_col1, #T_415c5_row1_col0, #T_415c5_row1_col1, #T_415c5_row2_col0, #T_415c5_row2_col1, #T_415c5_row3_col1, #T_415c5_row4_col0, #T_415c5_row4_col1, #T_415c5_row5_col1, #T_415c5_row6_col0, #T_415c5_row6_col1, #T_415c5_row7_col0, #T_415c5_row7_col1, #T_415c5_row8_col0, #T_415c5_row8_col1, #T_415c5_row9_col0, #T_415c5_row9_col1 {
#   background-color: #fdfdff;
#   color: #000000;
#   white-space: pre-wrap;
# }
# #T_415c5_row0_col2, #T_415c5_row1_col2, #T_415c5_row2_col2, #T_415c5_row3_col2, #T_415c5_row4_col2, #T_415c5_row5_col2, #T_415c5_row6_col2, #T_415c5_row7_col2, #T_415c5_row8_col2, #T_415c5_row9_col2 {
#   background-color: #fffdfd;
#   color: #000000;
#   white-space: pre-wrap;
# }
# #T_415c5_row0_col3, #T_415c5_row0_col4, #T_415c5_row1_col3, #T_415c5_row1_col4, #T_415c5_row2_col3, #T_415c5_row2_col4, #T_415c5_row3_col3, #T_415c5_row3_col4, #T_415c5_row4_col3, #T_415c5_row4_col4, #T_415c5_row5_col3, #T_415c5_row5_col4, #T_415c5_row6_col3, #T_415c5_row6_col4, #T_415c5_row7_col3, #T_415c5_row7_col4, #T_415c5_row8_col3, #T_415c5_row8_col4, #T_415c5_row9_col3, #T_415c5_row9_col4 {
#   white-space: pre-wrap;
# }
# #T_415c5_row3_col0 {
#   background-color: #f20000;
#   color: #f1f1f1;
#   white-space: pre-wrap;
# }
# #T_415c5_row5_col0 {
#   background-color: #ff6969;
#   color: #f1f1f1;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_415c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_415c5_level0_col0" class="col_heading level0 col0" >13 (0)</th>
#       <th id="T_415c5_level0_col1" class="col_heading level0 col1" > minutes (1)</th>
#       <th id="T_415c5_level0_col2" class="col_heading level0 col2" >. (2)</th>
#       <th id="T_415c5_level0_col3" class="col_heading level0 col3" >perturbed_input</th>
#       <th id="T_415c5_level0_col4" class="col_heading level0 col4" >perturbed_output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_415c5_level0_row0" class="row_heading level0 row0" >The (0)</th>
#       <td id="T_415c5_row0_col0" class="data row0 col0" >-0.000000</td>
#       <td id="T_415c5_row0_col1" class="data row0 col1" >-0.000000</td>
#       <td id="T_415c5_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_415c5_row0_col3" class="data row0 col3" >clock shows 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_415c5_row0_col4" class="data row0 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_415c5_level0_row1" class="row_heading level0 row1" > clock (1)</th>
#       <td id="T_415c5_row1_col0" class="data row1 col0" >-0.000000</td>
#       <td id="T_415c5_row1_col1" class="data row1 col1" >-0.000000</td>
#       <td id="T_415c5_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_415c5_row1_col3" class="data row1 col3" >The shows 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_415c5_row1_col4" class="data row1 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_415c5_level0_row2" class="row_heading level0 row2" > shows (2)</th>
#       <td id="T_415c5_row2_col0" class="data row2 col0" >-0.000000</td>
#       <td id="T_415c5_row2_col1" class="data row2 col1" >-0.000000</td>
#       <td id="T_415c5_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_415c5_row2_col3" class="data row2 col3" >The clock 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_415c5_row2_col4" class="data row2 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_415c5_level0_row3" class="row_heading level0 row3" > 9:47 (3)</th>
#       <td id="T_415c5_row3_col0" class="data row3 col0" >0.549087</td>
#       <td id="T_415c5_row3_col1" class="data row3 col1" >-0.000000</td>
#       <td id="T_415c5_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_415c5_row3_col3" class="data row3 col3" >The clock shows PM. How many minutes 'til 10?</td>
#       <td id="T_415c5_row3_col4" class="data row3 col4" >There are 120 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_415c5_level0_row4" class="row_heading level0 row4" > PM. (4)</th>
#       <td id="T_415c5_row4_col0" class="data row4 col0" >-0.000000</td>
#       <td id="T_415c5_row4_col1" class="data row4 col1" >-0.000000</td>
#       <td id="T_415c5_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_415c5_row4_col3" class="data row4 col3" >The clock shows 9:47 How many minutes 'til 10?</td>
#       <td id="T_415c5_row4_col4" class="data row4 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_415c5_level0_row5" class="row_heading level0 row5" > How (5)</th>
#       <td id="T_415c5_row5_col0" class="data row5 col0" >0.294424</td>
#       <td id="T_415c5_row5_col1" class="data row5 col1" >-0.000000</td>
#       <td id="T_415c5_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_415c5_row5_col3" class="data row5 col3" >The clock shows 9:47 PM. many minutes 'til 10?</td>
#       <td id="T_415c5_row5_col4" class="data row5 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_415c5_level0_row6" class="row_heading level0 row6" > many (6)</th>
#       <td id="T_415c5_row6_col0" class="data row6 col0" >-0.000000</td>
#       <td id="T_415c5_row6_col1" class="data row6 col1" >-0.000000</td>
#       <td id="T_415c5_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_415c5_row6_col3" class="data row6 col3" >The clock shows 9:47 PM. How minutes 'til 10?</td>
#       <td id="T_415c5_row6_col4" class="data row6 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_415c5_level0_row7" class="row_heading level0 row7" > minutes (7)</th>
#       <td id="T_415c5_row7_col0" class="data row7 col0" >-0.000000</td>
#       <td id="T_415c5_row7_col1" class="data row7 col1" >-0.000000</td>
#       <td id="T_415c5_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_415c5_row7_col3" class="data row7 col3" >The clock shows 9:47 PM. How many 'til 10?</td>
#       <td id="T_415c5_row7_col4" class="data row7 col4" >13 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_415c5_level0_row8" class="row_heading level0 row8" > 'til (8)</th>
#       <td id="T_415c5_row8_col0" class="data row8 col0" >-0.000000</td>
#       <td id="T_415c5_row8_col1" class="data row8 col1" >-0.000000</td>
#       <td id="T_415c5_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_415c5_row8_col3" class="data row8 col3" >The clock shows 9:47 PM. How many minutes 10?</td>
#       <td id="T_415c5_row8_col4" class="data row8 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_415c5_level0_row9" class="row_heading level0 row9" > 10? (9)</th>
#       <td id="T_415c5_row9_col0" class="data row9 col0" >-0.000000</td>
#       <td id="T_415c5_row9_col1" class="data row9 col1" >-0.000000</td>
#       <td id="T_415c5_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_415c5_row9_col3" class="data row9 col3" >The clock shows 9:47 PM. How many minutes 'til</td>
#       <td id="T_415c5_row9_col4" class="data row9 col4" >13 minutes.</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_64f17_row0_col0, #T_64f17_row4_col2 {
#   background-color: #ffadad;
#   color: #000000;
#   white-space: pre-wrap;
# }
# #T_64f17_row0_col1, #T_64f17_row2_col1, #T_64f17_row3_col1 {
#   background-color: #fdfdff;
#   color: #000000;
#   white-space: pre-wrap;
# }
# #T_64f17_row0_col2, #T_64f17_row1_col1, #T_64f17_row4_col1, #T_64f17_row5_col1, #T_64f17_row6_col1, #T_64f17_row7_col1, #T_64f17_row8_col1, #T_64f17_row9_col1 {
#   background-color: #fffdfd;
#   color: #000000;
#   white-space: pre-wrap;
# }
# #T_64f17_row0_col3, #T_64f17_row0_col4, #T_64f17_row1_col3, #T_64f17_row1_col4, #T_64f17_row2_col3, #T_64f17_row2_col4, #T_64f17_row3_col3, #T_64f17_row3_col4, #T_64f17_row4_col3, #T_64f17_row4_col4, #T_64f17_row5_col3, #T_64f17_row5_col4, #T_64f17_row6_col3, #T_64f17_row6_col4, #T_64f17_row7_col3, #T_64f17_row7_col4, #T_64f17_row8_col3, #T_64f17_row8_col4, #T_64f17_row9_col3, #T_64f17_row9_col4 {
#   white-space: pre-wrap;
# }
# #T_64f17_row1_col0, #T_64f17_row6_col0 {
#   background-color: #ffb1b1;
#   color: #000000;
#   white-space: pre-wrap;
# }
# #T_64f17_row1_col2 {
#   background-color: #ffbdbd;
#   color: #000000;
#   white-space: pre-wrap;
# }
# #T_64f17_row2_col0 {
#   background-color: #ffc5c5;
#   color: #000000;
#   white-space: pre-wrap;
# }
# #T_64f17_row2_col2 {
#   background-color: #ffe1e1;
#   color: #000000;
#   white-space: pre-wrap;
# }
# #T_64f17_row3_col0 {
#   background-color: #ca0000;
#   color: #f1f1f1;
#   white-space: pre-wrap;
# }
# #T_64f17_row3_col2 {
#   background-color: #6d6dff;
#   color: #f1f1f1;
#   white-space: pre-wrap;
# }
# #T_64f17_row4_col0 {
#   background-color: #ffd5d5;
#   color: #000000;
#   white-space: pre-wrap;
# }
# #T_64f17_row5_col0 {
#   background-color: #6969ff;
#   color: #f1f1f1;
#   white-space: pre-wrap;
# }
# #T_64f17_row5_col2 {
#   background-color: #7171ff;
#   color: #f1f1f1;
#   white-space: pre-wrap;
# }
# #T_64f17_row6_col2 {
#   background-color: #ff9999;
#   color: #000000;
#   white-space: pre-wrap;
# }
# #T_64f17_row7_col0 {
#   background-color: #ff6565;
#   color: #f1f1f1;
#   white-space: pre-wrap;
# }
# #T_64f17_row7_col2 {
#   background-color: #7d7dff;
#   color: #f1f1f1;
#   white-space: pre-wrap;
# }
# #T_64f17_row8_col0 {
#   background-color: #f1f1ff;
#   color: #000000;
#   white-space: pre-wrap;
# }
# #T_64f17_row8_col2 {
#   background-color: #ff7171;
#   color: #f1f1f1;
#   white-space: pre-wrap;
# }
# #T_64f17_row9_col0 {
#   background-color: #8d8dff;
#   color: #f1f1f1;
#   white-space: pre-wrap;
# }
# #T_64f17_row9_col2 {
#   background-color: #ff6161;
#   color: #f1f1f1;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_64f17">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64f17_level0_col0" class="col_heading level0 col0" >13 (0)</th>
#       <th id="T_64f17_level0_col1" class="col_heading level0 col1" > minutes (1)</th>
#       <th id="T_64f17_level0_col2" class="col_heading level0 col2" >. (2)</th>
#       <th id="T_64f17_level0_col3" class="col_heading level0 col3" >perturbed_input</th>
#       <th id="T_64f17_level0_col4" class="col_heading level0 col4" >perturbed_output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64f17_level0_row0" class="row_heading level0 row0" >The (0)</th>
#       <td id="T_64f17_row0_col0" class="data row0 col0" >0.162908</td>
#       <td id="T_64f17_row0_col1" class="data row0 col1" >-0.000006</td>
#       <td id="T_64f17_row0_col2" class="data row0 col2" >0.006028</td>
#       <td id="T_64f17_row0_col3" class="data row0 col3" >clock shows 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_64f17_row0_col4" class="data row0 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_64f17_level0_row1" class="row_heading level0 row1" > clock (1)</th>
#       <td id="T_64f17_row1_col0" class="data row1 col0" >0.150609</td>
#       <td id="T_64f17_row1_col1" class="data row1 col1" >0.000011</td>
#       <td id="T_64f17_row1_col2" class="data row1 col2" >0.131442</td>
#       <td id="T_64f17_row1_col3" class="data row1 col3" >The shows 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_64f17_row1_col4" class="data row1 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_64f17_level0_row2" class="row_heading level0 row2" > shows (2)</th>
#       <td id="T_64f17_row2_col0" class="data row2 col0" >0.113110</td>
#       <td id="T_64f17_row2_col1" class="data row2 col1" >-0.000025</td>
#       <td id="T_64f17_row2_col2" class="data row2 col2" >0.058145</td>
#       <td id="T_64f17_row2_col3" class="data row2 col3" >The clock 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_64f17_row2_col4" class="data row2 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_64f17_level0_row3" class="row_heading level0 row3" > 9:47 (3)</th>
#       <td id="T_64f17_row3_col0" class="data row3 col0" >0.708682</td>
#       <td id="T_64f17_row3_col1" class="data row3 col1" >-0.000074</td>
#       <td id="T_64f17_row3_col2" class="data row3 col2" >-0.283417</td>
#       <td id="T_64f17_row3_col3" class="data row3 col3" >The clock shows PM. How many minutes 'til 10?</td>
#       <td id="T_64f17_row3_col4" class="data row3 col4" >There are 120 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_64f17_level0_row4" class="row_heading level0 row4" > PM. (4)</th>
#       <td id="T_64f17_row4_col0" class="data row4 col0" >0.082562</td>
#       <td id="T_64f17_row4_col1" class="data row4 col1" >0.000027</td>
#       <td id="T_64f17_row4_col2" class="data row4 col2" >0.161614</td>
#       <td id="T_64f17_row4_col3" class="data row4 col3" >The clock shows 9:47 How many minutes 'til 10?</td>
#       <td id="T_64f17_row4_col4" class="data row4 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_64f17_level0_row5" class="row_heading level0 row5" > How (5)</th>
#       <td id="T_64f17_row5_col0" class="data row5 col0" >-0.291301</td>
#       <td id="T_64f17_row5_col1" class="data row5 col1" >0.000541</td>
#       <td id="T_64f17_row5_col2" class="data row5 col2" >-0.276476</td>
#       <td id="T_64f17_row5_col3" class="data row5 col3" >The clock shows 9:47 PM. many minutes 'til 10?</td>
#       <td id="T_64f17_row5_col4" class="data row5 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_64f17_level0_row6" class="row_heading level0 row6" > many (6)</th>
#       <td id="T_64f17_row6_col0" class="data row6 col0" >0.152962</td>
#       <td id="T_64f17_row6_col1" class="data row6 col1" >0.000077</td>
#       <td id="T_64f17_row6_col2" class="data row6 col2" >0.196756</td>
#       <td id="T_64f17_row6_col3" class="data row6 col3" >The clock shows 9:47 PM. How minutes 'til 10?</td>
#       <td id="T_64f17_row6_col4" class="data row6 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_64f17_level0_row7" class="row_heading level0 row7" > minutes (7)</th>
#       <td id="T_64f17_row7_col0" class="data row7 col0" >0.297542</td>
#       <td id="T_64f17_row7_col1" class="data row7 col1" >0.001325</td>
#       <td id="T_64f17_row7_col2" class="data row7 col2" >-0.253335</td>
#       <td id="T_64f17_row7_col3" class="data row7 col3" >The clock shows 9:47 PM. How many 'til 10?</td>
#       <td id="T_64f17_row7_col4" class="data row7 col4" >13 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_64f17_level0_row8" class="row_heading level0 row8" > 'til (8)</th>
#       <td id="T_64f17_row8_col0" class="data row8 col0" >-0.031198</td>
#       <td id="T_64f17_row8_col1" class="data row8 col1" >0.001080</td>
#       <td id="T_64f17_row8_col2" class="data row8 col2" >0.275402</td>
#       <td id="T_64f17_row8_col3" class="data row8 col3" >The clock shows 9:47 PM. How many minutes 10?</td>
#       <td id="T_64f17_row8_col4" class="data row8 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_64f17_level0_row9" class="row_heading level0 row9" > 10? (9)</th>
#       <td id="T_64f17_row9_col0" class="data row9 col0" >-0.220716</td>
#       <td id="T_64f17_row9_col1" class="data row9 col1" >0.000844</td>
#       <td id="T_64f17_row9_col2" class="data row9 col2" >0.306712</td>
#       <td id="T_64f17_row9_col3" class="data row9 col3" >The clock shows 9:47 PM. How many minutes 'til</td>
#       <td id="T_64f17

# %%
logger.df_experiments
# Out:
#    exp_id                                     original_input original_output  \
# 0       1  The clock shows 9:47 PM. How many minutes 'til...     13 minutes.
# 1       2  The clock shows 9:47 PM. How many minutes 'til...     13 minutes.
# 2       3  The clock shows 9:47 PM. How many minutes 'til...     13 minutes.
#
#   perturbation_strategy unit_definition  duration num_llm_calls
# 0                 fixed            word  1.174003            11
# 1     nth_nearest (n=0)            word   3.70429            11
# 2    nth_nearest (n=-1)            word  4.377963            11
