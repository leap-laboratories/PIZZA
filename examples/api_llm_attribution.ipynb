# %%
# Re-import modified modules without restarting the server
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import warnings

notebook_path = os.path.abspath(get_ipython().starting_dir)
parent_path = os.path.dirname(notebook_path)

sys.path.append(parent_path)
warnings.simplefilter("ignore")

# %%
from attribution.api_attribution import OpenAIAttributor
from attribution.experiment_logger import ExperimentLogger
from attribution.token_perturbation import (
    FixedPerturbationStrategy,
    NthNearestPerturbationStrategy,
)

# %%
attributor = OpenAIAttributor()
logger = ExperimentLogger()
attributor.compute_attributions(
    "The clock shows 9:47 PM. How many minutes 'til 10?",
    perturbation_strategy=NthNearestPerturbationStrategy(n=-1),
    attribution_strategies=["cosine"],
    logger=logger,
    perturb_word_wise=True,
)
display(logger.df_experiments)
logger.print_sentence_attribution()
logger.print_attribution_matrix(exp_id=1)
# Out:
#    exp_id                                     original_input  \
# 0       1  The clock shows 9:47 PM. How many minutes 'til...
#
#                         original_output perturbation_strategy  \
# 0  There are 13 minutes until 10:00 PM.    nth_nearest (n=-1)
#
#    perturb_word_wise  duration
# 0               True  8.201979
# <style type="text/css">
# #T_ed681_row0_col0, #T_ed681_row0_col1, #T_ed681_row0_col2, #T_ed681_row0_col3, #T_ed681_row0_col4, #T_ed681_row0_col5, #T_ed681_row0_col6, #T_ed681_row0_col7, #T_ed681_row0_col8, #T_ed681_row0_col9, #T_ed681_row0_col10, #T_ed681_row0_col11, #T_ed681_row0_col12, #T_ed681_row0_col13, #T_ed681_row0_col14, #T_ed681_row0_col15, #T_ed681_row0_col16, #T_ed681_row0_col17, #T_ed681_row0_col18 {
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_ed681">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed681_level0_col0" class="col_heading level0 col0" >exp_id</th>
#       <th id="T_ed681_level0_col1" class="col_heading level0 col1" >attribution_strategy</th>
#       <th id="T_ed681_level0_col2" class="col_heading level0 col2" >perturbation_strategy</th>
#       <th id="T_ed681_level0_col3" class="col_heading level0 col3" >perturb_word_wise</th>
#       <th id="T_ed681_level0_col4" class="col_heading level0 col4" >token_1</th>
#       <th id="T_ed681_level0_col5" class="col_heading level0 col5" >token_2</th>
#       <th id="T_ed681_level0_col6" class="col_heading level0 col6" >token_3</th>
#       <th id="T_ed681_level0_col7" class="col_heading level0 col7" >token_4</th>
#       <th id="T_ed681_level0_col8" class="col_heading level0 col8" >token_5</th>
#       <th id="T_ed681_level0_col9" class="col_heading level0 col9" >token_6</th>
#       <th id="T_ed681_level0_col10" class="col_heading level0 col10" >token_7</th>
#       <th id="T_ed681_level0_col11" class="col_heading level0 col11" >token_8</th>
#       <th id="T_ed681_level0_col12" class="col_heading level0 col12" >token_9</th>
#       <th id="T_ed681_level0_col13" class="col_heading level0 col13" >token_10</th>
#       <th id="T_ed681_level0_col14" class="col_heading level0 col14" >token_11</th>
#       <th id="T_ed681_level0_col15" class="col_heading level0 col15" >token_12</th>
#       <th id="T_ed681_level0_col16" class="col_heading level0 col16" >token_13</th>
#       <th id="T_ed681_level0_col17" class="col_heading level0 col17" >token_14</th>
#       <th id="T_ed681_level0_col18" class="col_heading level0 col18" >token_15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed681_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ed681_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ed681_row0_col1" class="data row0 col1" >cosine</td>
#       <td id="T_ed681_row0_col2" class="data row0 col2" >nth_nearest (n=-1)</td>
#       <td id="T_ed681_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_ed681_row0_col4" class="data row0 col4" >The
# 0.00</td>
#       <td id="T_ed681_row0_col5" class="data row0 col5" >clock
# 0.21</td>
#       <td id="T_ed681_row0_col6" class="data row0 col6" >shows
# 0.21</td>
#       <td id="T_ed681_row0_col7" class="data row0 col7" >9
# 0.06</td>
#       <td id="T_ed681_row0_col8" class="data row0 col8" >:
# 0.06</td>
#       <td id="T_ed681_row0_col9" class="data row0 col9" >47
# 0.06</td>
#       <td id="T_ed681_row0_col10" class="data row0 col10" >PM
# 0.08</td>
#       <td id="T_ed681_row0_col11" class="data row0 col11" >.
# 0.08</td>
#       <td id="T_ed681_row0_col12" class="data row0 col12" >How
# 0.00</td>
#       <td id="T_ed681_row0_col13" class="data row0 col13" >many
# 0.00</td>
#       <td id="T_ed681_row0_col14" class="data row0 col14" >minutes
# 0.23</td>
#       <td id="T_ed681_row0_col15" class="data row0 col15" >'
# 0.27</td>
#       <td id="T_ed681_row0_col16" class="data row0 col16" >til
# 0.27</td>
#       <td id="T_ed681_row0_col17" class="data row0 col17" >10
# 0.27</td>
#       <td id="T_ed681_row0_col18" class="data row0 col18" >?
# 0.27</td>
#     </tr>
#   </tbody>
# </table>
# Attribution matrix for experiment 1
# Attribution Strategy: cosine
# Perturbation strategy: nth_nearest (n=-1):
# Input Tokens (Rows) vs. Output Tokens (Columns)
# <style type="text/css">
# #T_5329c_row0_col0, #T_5329c_row0_col1, #T_5329c_row0_col2, #T_5329c_row0_col3, #T_5329c_row0_col4, #T_5329c_row0_col5, #T_5329c_row0_col6, #T_5329c_row0_col7, #T_5329c_row0_col8, #T_5329c_row0_col9, #T_5329c_row1_col3, #T_5329c_row1_col9, #T_5329c_row2_col3, #T_5329c_row2_col9, #T_5329c_row3_col0, #T_5329c_row3_col1, #T_5329c_row3_col3, #T_5329c_row3_col4, #T_5329c_row3_col5, #T_5329c_row3_col8, #T_5329c_row3_col9, #T_5329c_row4_col0, #T_5329c_row4_col1, #T_5329c_row4_col3, #T_5329c_row4_col4, #T_5329c_row4_col5, #T_5329c_row4_col8, #T_5329c_row4_col9, #T_5329c_row5_col0, #T_5329c_row5_col1, #T_5329c_row5_col3, #T_5329c_row5_col4, #T_5329c_row5_col5, #T_5329c_row5_col8, #T_5329c_row5_col9, #T_5329c_row6_col0, #T_5329c_row6_col1, #T_5329c_row6_col2, #T_5329c_row6_col3, #T_5329c_row6_col4, #T_5329c_row6_col5, #T_5329c_row6_col9, #T_5329c_row7_col0, #T_5329c_row7_col1, #T_5329c_row7_col2, #T_5329c_row7_col3, #T_5329c_row7_col4, #T_5329c_row7_col5, #T_5329c_row7_col9, #T_5329c_row8_col0, #T_5329c_row8_col1, #T_5329c_row8_col2, #T_5329c_row8_col3, #T_5329c_row8_col4, #T_5329c_row8_col5, #T_5329c_row8_col6, #T_5329c_row8_col7, #T_5329c_row8_col8, #T_5329c_row8_col9, #T_5329c_row9_col0, #T_5329c_row9_col1, #T_5329c_row9_col2, #T_5329c_row9_col3, #T_5329c_row9_col4, #T_5329c_row9_col5, #T_5329c_row9_col6, #T_5329c_row9_col7, #T_5329c_row9_col8, #T_5329c_row9_col9, #T_5329c_row10_col3, #T_5329c_row10_col9, #T_5329c_row11_col3, #T_5329c_row12_col3, #T_5329c_row13_col3, #T_5329c_row14_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_5329c_row1_col0, #T_5329c_row1_col8, #T_5329c_row2_col0, #T_5329c_row2_col8, #T_5329c_row10_col2, #T_5329c_row10_col5, #T_5329c_row10_col7, #T_5329c_row10_col8, #T_5329c_row11_col0, #T_5329c_row11_col1, #T_5329c_row11_col4, #T_5329c_row11_col6, #T_5329c_row11_col8, #T_5329c_row11_col9, #T_5329c_row12_col0, #T_5329c_row12_col1, #T_5329c_row12_col4, #T_5329c_row12_col6, #T_5329c_row12_col8, #T_5329c_row12_col9, #T_5329c_row13_col0, #T_5329c_row13_col1, #T_5329c_row13_col4, #T_5329c_row13_col6, #T_5329c_row13_col8, #T_5329c_row13_col9, #T_5329c_row14_col0, #T_5329c_row14_col1, #T_5329c_row14_col4, #T_5329c_row14_col6, #T_5329c_row14_col8, #T_5329c_row14_col9 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_5329c_row1_col1, #T_5329c_row2_col1, #T_5329c_row10_col1 {
#   background-color: #d00d21;
#   color: #f1f1f1;
# }
# #T_5329c_row1_col2, #T_5329c_row2_col2, #T_5329c_row11_col2, #T_5329c_row12_col2, #T_5329c_row13_col2, #T_5329c_row14_col2 {
#   background-color: #fd8239;
#   color: #f1f1f1;
# }
# #T_5329c_row1_col4, #T_5329c_row2_col4, #T_5329c_row10_col4 {
#   background-color: #8f0026;
#   color: #f1f1f1;
# }
# #T_5329c_row1_col5, #T_5329c_row2_col5, #T_5329c_row11_col5, #T_5329c_row12_col5, #T_5329c_row13_col5, #T_5329c_row14_col5 {
#   background-color: #be0126;
#   color: #f1f1f1;
# }
# #T_5329c_row1_col6, #T_5329c_row2_col6, #T_5329c_row6_col6, #T_5329c_row7_col6, #T_5329c_row10_col6 {
#   background-color: #feae4a;
#   color: #000000;
# }
# #T_5329c_row1_col7, #T_5329c_row2_col7, #T_5329c_row11_col7, #T_5329c_row12_col7, #T_5329c_row13_col7, #T_5329c_row14_col7 {
#   background-color: #e61f1d;
#   color: #f1f1f1;
# }
# #T_5329c_row3_col2, #T_5329c_row4_col2, #T_5329c_row5_col2 {
#   background-color: #fd7a37;
#   color: #f1f1f1;
# }
# #T_5329c_row3_col6, #T_5329c_row4_col6, #T_5329c_row5_col6 {
#   background-color: #feb04b;
#   color: #000000;
# }
# #T_5329c_row3_col7, #T_5329c_row4_col7, #T_5329c_row5_col7 {
#   background-color: #9d0026;
#   color: #f1f1f1;
# }
# #T_5329c_row6_col7, #T_5329c_row7_col7 {
#   background-color: #910026;
#   color: #f1f1f1;
# }
# #T_5329c_row6_col8, #T_5329c_row7_col8 {
#   background-color: #860026;
#   color: #f1f1f1;
# }
# #T_5329c_row10_col0 {
#   background-color: #9b0026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5329c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5329c_level0_col0" class="col_heading level0 col0" >There (0)</th>
#       <th id="T_5329c_level0_col1" class="col_heading level0 col1" > are (1)</th>
#       <th id="T_5329c_level0_col2" class="col_heading level0 col2" >  (2)</th>
#       <th id="T_5329c_level0_col3" class="col_heading level0 col3" >13 (3)</th>
#       <th id="T_5329c_level0_col4" class="col_heading level0 col4" > minutes (4)</th>
#       <th id="T_5329c_level0_col5" class="col_heading level0 col5" > until (5)</th>
#       <th id="T_5329c_level0_col6" class="col_heading level0 col6" >  (6)</th>
#       <th id="T_5329c_level0_col7" class="col_heading level0 col7" >10 (7)</th>
#       <th id="T_5329c_level0_col8" class="col_heading level0 col8" >: (8)</th>
#       <th id="T_5329c_level0_col9" class="col_heading level0 col9" >00 (9)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5329c_level0_row0" class="row_heading level0 row0" >The (0)</th>
#       <td id="T_5329c_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_5329c_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_5329c_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_5329c_row0_col3" class="data row0 col3" >-0.000000</td>
#       <td id="T_5329c_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_5329c_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_5329c_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_5329c_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_5329c_row0_col8" class="data row0 col8" >-0.000000</td>
#       <td id="T_5329c_row0_col9" class="data row0 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5329c_level0_row1" class="row_heading level0 row1" >clock (1)</th>
#       <td id="T_5329c_row1_col0" class="data row1 col0" >0.300173</td>
#       <td id="T_5329c_row1_col1" class="data row1 col1" >0.267897</td>
#       <td id="T_5329c_row1_col2" class="data row1 col2" >0.147212</td>
#       <td id="T_5329c_row1_col3" class="data row1 col3" >-0.000000</td>
#       <td id="T_5329c_row1_col4" class="data row1 col4" >0.335434</td>
#       <td id="T_5329c_row1_col5" class="data row1 col5" >0.274544</td>
#       <td id="T_5329c_row1_col6" class="data row1 col6" >0.135710</td>
#       <td id="T_5329c_row1_col7" class="data row1 col7" >0.263017</td>
#       <td id="T_5329c_row1_col8" class="data row1 col8" >0.373404</td>
#       <td id="T_5329c_row1_col9" class="data row1 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5329c_level0_row2" class="row_heading level0 row2" >shows (2)</th>
#       <td id="T_5329c_row2_col0" class="data row2 col0" >0.300173</td>
#       <td id="T_5329c_row2_col1" class="data row2 col1" >0.267897</td>
#       <td id="T_5329c_row2_col2" class="data row2 col2" >0.147212</td>
#       <td id="T_5329c_row2_col3" class="data row2 col3" >-0.000000</td>
#       <td id="T_5329c_row2_col4" class="data row2 col4" >0.335434</td>
#       <td id="T_5329c_row2_col5" class="data row2 col5" >0.274544</td>
#       <td id="T_5329c_row2_col6" class="data row2 col6" >0.135710</td>
#       <td id="T_5329c_row2_col7" class="data row2 col7" >0.263017</td>
#       <td id="T_5329c_row2_col8" class="data row2 col8" >0.373404</td>
#       <td id="T_5329c_row2_col9" class="data row2 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5329c_level0_row3" class="row_heading level0 row3" >9 (3)</th>
#       <td id="T_5329c_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_5329c_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_5329c_row3_col2" class="data row3 col2" >0.151307</td>
#       <td id="T_5329c_row3_col3" class="data row3 col3" >-0.000000</td>
#       <td id="T_5329c_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_5329c_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_5329c_row3_col6" class="data row3 col6" >0.133127</td>
#       <td id="T_5329c_row3_col7" class="data row3 col7" >0.334932</td>
#       <td id="T_5329c_row3_col8" class="data row3 col8" >-0.000000</td>
#       <td id="T_5329c_row3_col9" class="data row3 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5329c_level0_row4

# %%
logger.print_attribution_matrix(exp_id=1, show_debug_cols=True)
# Out:
# Attribution matrix for experiment 1
# Attribution Strategy: cosine
# Perturbation strategy: nth_nearest (n=-1):
# Input Tokens (Rows) vs. Output Tokens (Columns)
# <style type="text/css">
# #T_6f07e_row0_col0, #T_6f07e_row0_col1, #T_6f07e_row0_col2, #T_6f07e_row0_col3, #T_6f07e_row0_col4, #T_6f07e_row0_col5, #T_6f07e_row0_col6, #T_6f07e_row0_col7, #T_6f07e_row0_col8, #T_6f07e_row0_col9, #T_6f07e_row1_col3, #T_6f07e_row1_col9, #T_6f07e_row2_col3, #T_6f07e_row2_col9, #T_6f07e_row3_col0, #T_6f07e_row3_col1, #T_6f07e_row3_col3, #T_6f07e_row3_col4, #T_6f07e_row3_col5, #T_6f07e_row3_col8, #T_6f07e_row3_col9, #T_6f07e_row4_col0, #T_6f07e_row4_col1, #T_6f07e_row4_col3, #T_6f07e_row4_col4, #T_6f07e_row4_col5, #T_6f07e_row4_col8, #T_6f07e_row4_col9, #T_6f07e_row5_col0, #T_6f07e_row5_col1, #T_6f07e_row5_col3, #T_6f07e_row5_col4, #T_6f07e_row5_col5, #T_6f07e_row5_col8, #T_6f07e_row5_col9, #T_6f07e_row6_col0, #T_6f07e_row6_col1, #T_6f07e_row6_col2, #T_6f07e_row6_col3, #T_6f07e_row6_col4, #T_6f07e_row6_col5, #T_6f07e_row6_col9, #T_6f07e_row7_col0, #T_6f07e_row7_col1, #T_6f07e_row7_col2, #T_6f07e_row7_col3, #T_6f07e_row7_col4, #T_6f07e_row7_col5, #T_6f07e_row7_col9, #T_6f07e_row8_col0, #T_6f07e_row8_col1, #T_6f07e_row8_col2, #T_6f07e_row8_col3, #T_6f07e_row8_col4, #T_6f07e_row8_col5, #T_6f07e_row8_col6, #T_6f07e_row8_col7, #T_6f07e_row8_col8, #T_6f07e_row8_col9, #T_6f07e_row9_col0, #T_6f07e_row9_col1, #T_6f07e_row9_col2, #T_6f07e_row9_col3, #T_6f07e_row9_col4, #T_6f07e_row9_col5, #T_6f07e_row9_col6, #T_6f07e_row9_col7, #T_6f07e_row9_col8, #T_6f07e_row9_col9, #T_6f07e_row10_col3, #T_6f07e_row10_col9, #T_6f07e_row11_col3, #T_6f07e_row12_col3, #T_6f07e_row13_col3, #T_6f07e_row14_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_6f07e_row1_col0, #T_6f07e_row1_col8, #T_6f07e_row2_col0, #T_6f07e_row2_col8, #T_6f07e_row10_col2, #T_6f07e_row10_col5, #T_6f07e_row10_col7, #T_6f07e_row10_col8, #T_6f07e_row11_col0, #T_6f07e_row11_col1, #T_6f07e_row11_col4, #T_6f07e_row11_col6, #T_6f07e_row11_col8, #T_6f07e_row11_col9, #T_6f07e_row12_col0, #T_6f07e_row12_col1, #T_6f07e_row12_col4, #T_6f07e_row12_col6, #T_6f07e_row12_col8, #T_6f07e_row12_col9, #T_6f07e_row13_col0, #T_6f07e_row13_col1, #T_6f07e_row13_col4, #T_6f07e_row13_col6, #T_6f07e_row13_col8, #T_6f07e_row13_col9, #T_6f07e_row14_col0, #T_6f07e_row14_col1, #T_6f07e_row14_col4, #T_6f07e_row14_col6, #T_6f07e_row14_col8, #T_6f07e_row14_col9 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_6f07e_row1_col1, #T_6f07e_row2_col1, #T_6f07e_row10_col1 {
#   background-color: #d00d21;
#   color: #f1f1f1;
# }
# #T_6f07e_row1_col2, #T_6f07e_row2_col2, #T_6f07e_row11_col2, #T_6f07e_row12_col2, #T_6f07e_row13_col2, #T_6f07e_row14_col2 {
#   background-color: #fd8239;
#   color: #f1f1f1;
# }
# #T_6f07e_row1_col4, #T_6f07e_row2_col4, #T_6f07e_row10_col4 {
#   background-color: #8f0026;
#   color: #f1f1f1;
# }
# #T_6f07e_row1_col5, #T_6f07e_row2_col5, #T_6f07e_row11_col5, #T_6f07e_row12_col5, #T_6f07e_row13_col5, #T_6f07e_row14_col5 {
#   background-color: #be0126;
#   color: #f1f1f1;
# }
# #T_6f07e_row1_col6, #T_6f07e_row2_col6, #T_6f07e_row6_col6, #T_6f07e_row7_col6, #T_6f07e_row10_col6 {
#   background-color: #feae4a;
#   color: #000000;
# }
# #T_6f07e_row1_col7, #T_6f07e_row2_col7, #T_6f07e_row11_col7, #T_6f07e_row12_col7, #T_6f07e_row13_col7, #T_6f07e_row14_col7 {
#   background-color: #e61f1d;
#   color: #f1f1f1;
# }
# #T_6f07e_row3_col2, #T_6f07e_row4_col2, #T_6f07e_row5_col2 {
#   background-color: #fd7a37;
#   color: #f1f1f1;
# }
# #T_6f07e_row3_col6, #T_6f07e_row4_col6, #T_6f07e_row5_col6 {
#   background-color: #feb04b;
#   color: #000000;
# }
# #T_6f07e_row3_col7, #T_6f07e_row4_col7, #T_6f07e_row5_col7 {
#   background-color: #9d0026;
#   color: #f1f1f1;
# }
# #T_6f07e_row6_col7, #T_6f07e_row7_col7 {
#   background-color: #910026;
#   color: #f1f1f1;
# }
# #T_6f07e_row6_col8, #T_6f07e_row7_col8 {
#   background-color: #860026;
#   color: #f1f1f1;
# }
# #T_6f07e_row10_col0 {
#   background-color: #9b0026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6f07e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f07e_level0_col0" class="col_heading level0 col0" >There (0)</th>
#       <th id="T_6f07e_level0_col1" class="col_heading level0 col1" > are (1)</th>
#       <th id="T_6f07e_level0_col2" class="col_heading level0 col2" >  (2)</th>
#       <th id="T_6f07e_level0_col3" class="col_heading level0 col3" >13 (3)</th>
#       <th id="T_6f07e_level0_col4" class="col_heading level0 col4" > minutes (4)</th>
#       <th id="T_6f07e_level0_col5" class="col_heading level0 col5" > until (5)</th>
#       <th id="T_6f07e_level0_col6" class="col_heading level0 col6" >  (6)</th>
#       <th id="T_6f07e_level0_col7" class="col_heading level0 col7" >10 (7)</th>
#       <th id="T_6f07e_level0_col8" class="col_heading level0 col8" >: (8)</th>
#       <th id="T_6f07e_level0_col9" class="col_heading level0 col9" >00 (9)</th>
#       <th id="T_6f07e_level0_col10" class="col_heading level0 col10" >perturbed_input</th>
#       <th id="T_6f07e_level0_col11" class="col_heading level0 col11" >perturbed_output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f07e_level0_row0" class="row_heading level0 row0" >The (0)</th>
#       <td id="T_6f07e_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_6f07e_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_6f07e_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_6f07e_row0_col3" class="data row0 col3" >-0.000000</td>
#       <td id="T_6f07e_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_6f07e_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_6f07e_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_6f07e_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_6f07e_row0_col8" class="data row0 col8" >-0.000000</td>
#       <td id="T_6f07e_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_6f07e_row0_col10" class="data row0 col10" >EStreamFrame clock shows 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_6f07e_row0_col11" class="data row0 col11" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_6f07e_level0_row1" class="row_heading level0 row1" >clock (1)</th>
#       <td id="T_6f07e_row1_col0" class="data row1 col0" >0.300173</td>
#       <td id="T_6f07e_row1_col1" class="data row1 col1" >0.267897</td>
#       <td id="T_6f07e_row1_col2" class="data row1 col2" >0.147212</td>
#       <td id="T_6f07e_row1_col3" class="data row1 col3" >-0.000000</td>
#       <td id="T_6f07e_row1_col4" class="data row1 col4" >0.335434</td>
#       <td id="T_6f07e_row1_col5" class="data row1 col5" >0.274544</td>
#       <td id="T_6f07e_row1_col6" class="data row1 col6" >0.135710</td>
#       <td id="T_6f07e_row1_col7" class="data row1 col7" >0.263017</td>
#       <td id="T_6f07e_row1_col8" class="data row1 col8" >0.373404</td>
#       <td id="T_6f07e_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_6f07e_row1_col10" class="data row1 col10" >Theur shows 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_6f07e_row1_col11" class="data row1 col11" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_6f07e_level0_row2" class="row_heading level0 row2" >shows (2)</th>
#       <td id="T_6f07e_row2_col0" class="data row2 col0" >0.300173</td>
#       <td id="T_6f07e_row2_col1" class="data row2 col1" >0.267897</td>
#       <td id="T_6f07e_row2_col2" class="data row2 col2" >0.147212</td>
#       <td id="T_6f07e_row2_col3" class="data row2 col3" >-0.000000</td>
#       <td id="T_6f07e_row2_col4" class="data row2 col4" >0.335434</td>
#       <td id="T_6f07e_row2_col5" class="data row2 col5" >0.274544</td>
#       <td id="T_6f07e_row2_col6" class="data row2 col6" >0.135710</td>
#       <td id="T_6f07e_row2_col7" class="data row2 col7" >0.263017</td>
#       <td id="T_6f07e_row2_col8" class="data row2 col8" >0.373404</td>
#       <td id="T_6f07e_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_6f07e_row2_col10" class="data row2 col10" >The clocketooth 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_6f07e_row2_col11" class="data row2 col11" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_6f07e_level0_row3" class="row_heading lev

# %%
attributor = OpenAIAttributor()

input_texts = ["The clock shows 9:47 PM. How many minutes 'til 10?"]

perturbation_strategies = [
    FixedPerturbationStrategy(),
    NthNearestPerturbationStrategy(n=0),
    NthNearestPerturbationStrategy(n=-1),
    # (PerturbationStrategy.NTH_NEAREST, {"n": 10}),
]

# Initialize the logger
logger = ExperimentLogger()

# Perform the experiment
for input_text in input_texts:
    for perturbation_strategy in perturbation_strategies:
        attributor.compute_attributions(
            input_text,
            perturbation_strategy=perturbation_strategy,
            attribution_strategies=["cosine", "prob_diff"],
            logger=logger,
            perturb_word_wise=True,
        )

# Display the results
display(logger.df_experiments)
logger.print_sentence_attribution()
# Out:
#    exp_id                                     original_input original_output  \
# 0       1  The clock shows 9:47 PM. How many minutes 'til...     13 minutes.
# 1       2  The clock shows 9:47 PM. How many minutes 'til...     13 minutes.
# 2       3  The clock shows 9:47 PM. How many minutes 'til...     13 minutes.
#
#   perturbation_strategy  perturb_word_wise  duration
# 0                 fixed               True  8.115919
# 1     nth_nearest (n=0)               True  8.325179
# 2    nth_nearest (n=-1)               True  8.631807
# <style type="text/css">
# #T_3a72a_row0_col0, #T_3a72a_row0_col1, #T_3a72a_row0_col2, #T_3a72a_row0_col3, #T_3a72a_row0_col4, #T_3a72a_row0_col5, #T_3a72a_row0_col6, #T_3a72a_row0_col7, #T_3a72a_row0_col8, #T_3a72a_row0_col9, #T_3a72a_row0_col10, #T_3a72a_row0_col11, #T_3a72a_row0_col12, #T_3a72a_row0_col13, #T_3a72a_row0_col14, #T_3a72a_row0_col15, #T_3a72a_row0_col16, #T_3a72a_row0_col17, #T_3a72a_row0_col18, #T_3a72a_row1_col0, #T_3a72a_row1_col1, #T_3a72a_row1_col2, #T_3a72a_row1_col3, #T_3a72a_row1_col4, #T_3a72a_row1_col5, #T_3a72a_row1_col6, #T_3a72a_row1_col7, #T_3a72a_row1_col8, #T_3a72a_row1_col9, #T_3a72a_row1_col10, #T_3a72a_row1_col11, #T_3a72a_row1_col12, #T_3a72a_row1_col13, #T_3a72a_row1_col14, #T_3a72a_row1_col15, #T_3a72a_row1_col16, #T_3a72a_row1_col17, #T_3a72a_row1_col18, #T_3a72a_row2_col0, #T_3a72a_row2_col1, #T_3a72a_row2_col2, #T_3a72a_row2_col3, #T_3a72a_row2_col4, #T_3a72a_row2_col5, #T_3a72a_row2_col6, #T_3a72a_row2_col7, #T_3a72a_row2_col8, #T_3a72a_row2_col9, #T_3a72a_row2_col10, #T_3a72a_row2_col11, #T_3a72a_row2_col12, #T_3a72a_row2_col13, #T_3a72a_row2_col14, #T_3a72a_row2_col15, #T_3a72a_row2_col16, #T_3a72a_row2_col17, #T_3a72a_row2_col18, #T_3a72a_row3_col0, #T_3a72a_row3_col1, #T_3a72a_row3_col2, #T_3a72a_row3_col3, #T_3a72a_row3_col4, #T_3a72a_row3_col5, #T_3a72a_row3_col6, #T_3a72a_row3_col7, #T_3a72a_row3_col8, #T_3a72a_row3_col9, #T_3a72a_row3_col10, #T_3a72a_row3_col11, #T_3a72a_row3_col12, #T_3a72a_row3_col13, #T_3a72a_row3_col14, #T_3a72a_row3_col15, #T_3a72a_row3_col16, #T_3a72a_row3_col17, #T_3a72a_row3_col18, #T_3a72a_row4_col0, #T_3a72a_row4_col1, #T_3a72a_row4_col2, #T_3a72a_row4_col3, #T_3a72a_row4_col4, #T_3a72a_row4_col5, #T_3a72a_row4_col6, #T_3a72a_row4_col7, #T_3a72a_row4_col8, #T_3a72a_row4_col9, #T_3a72a_row4_col10, #T_3a72a_row4_col11, #T_3a72a_row4_col12, #T_3a72a_row4_col13, #T_3a72a_row4_col14, #T_3a72a_row4_col15, #T_3a72a_row4_col16, #T_3a72a_row4_col17, #T_3a72a_row4_col18, #T_3a72a_row5_col0, #T_3a72a_row5_col1, #T_3a72a_row5_col2, #T_3a72a_row5_col3, #T_3a72a_row5_col4, #T_3a72a_row5_col5, #T_3a72a_row5_col6, #T_3a72a_row5_col7, #T_3a72a_row5_col8, #T_3a72a_row5_col9, #T_3a72a_row5_col10, #T_3a72a_row5_col11, #T_3a72a_row5_col12, #T_3a72a_row5_col13, #T_3a72a_row5_col14, #T_3a72a_row5_col15, #T_3a72a_row5_col16, #T_3a72a_row5_col17, #T_3a72a_row5_col18 {
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_3a72a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a72a_level0_col0" class="col_heading level0 col0" >exp_id</th>
#       <th id="T_3a72a_level0_col1" class="col_heading level0 col1" >attribution_strategy</th>
#       <th id="T_3a72a_level0_col2" class="col_heading level0 col2" >perturbation_strategy</th>
#       <th id="T_3a72a_level0_col3" class="col_heading level0 col3" >perturb_word_wise</th>
#       <th id="T_3a72a_level0_col4" class="col_heading level0 col4" >token_1</th>
#       <th id="T_3a72a_level0_col5" class="col_heading level0 col5" >token_2</th>
#       <th id="T_3a72a_level0_col6" class="col_heading level0 col6" >token_3</th>
#       <th id="T_3a72a_level0_col7" class="col_heading level0 col7" >token_4</th>
#       <th id="T_3a72a_level0_col8" class="col_heading level0 col8" >token_5</th>
#       <th id="T_3a72a_level0_col9" class="col_heading level0 col9" >token_6</th>
#       <th id="T_3a72a_level0_col10" class="col_heading level0 col10" >token_7</th>
#       <th id="T_3a72a_level0_col11" class="col_heading level0 col11" >token_8</th>
#       <th id="T_3a72a_level0_col12" class="col_heading level0 col12" >token_9</th>
#       <th id="T_3a72a_level0_col13" class="col_heading level0 col13" >token_10</th>
#       <th id="T_3a72a_level0_col14" class="col_heading level0 col14" >token_11</th>
#       <th id="T_3a72a_level0_col15" class="col_heading level0 col15" >token_12</th>
#       <th id="T_3a72a_level0_col16" class="col_heading level0 col16" >token_13</th>
#       <th id="T_3a72a_level0_col17" class="col_heading level0 col17" >token_14</th>
#       <th id="T_3a72a_level0_col18" class="col_heading level0 col18" >token_15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a72a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a72a_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_3a72a_row0_col1" class="data row0 col1" >cosine</td>
#       <td id="T_3a72a_row0_col2" class="data row0 col2" >fixed</td>
#       <td id="T_3a72a_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_3a72a_row0_col4" class="data row0 col4" >The
# 0.05</td>
#       <td id="T_3a72a_row0_col5" class="data row0 col5" >clock
# 0.05</td>
#       <td id="T_3a72a_row0_col6" class="data row0 col6" >shows
# -0.00</td>
#       <td id="T_3a72a_row0_col7" class="data row0 col7" >9
# 0.09</td>
#       <td id="T_3a72a_row0_col8" class="data row0 col8" >:
# 0.09</td>
#       <td id="T_3a72a_row0_col9" class="data row0 col9" >47
# 0.09</td>
#       <td id="T_3a72a_row0_col10" class="data row0 col10" >PM
# -0.00</td>
#       <td id="T_3a72a_row0_col11" class="data row0 col11" >.
# -0.00</td>
#       <td id="T_3a72a_row0_col12" class="data row0 col12" >How
# 0.05</td>
#       <td id="T_3a72a_row0_col13" class="data row0 col13" >many
# 0.05</td>
#       <td id="T_3a72a_row0_col14" class="data row0 col14" >minutes
# -0.00</td>
#       <td id="T_3a72a_row0_col15" class="data row0 col15" >'
# -0.00</td>
#       <td id="T_3a72a_row0_col16" class="data row0 col16" >til
# -0.00</td>
#       <td id="T_3a72a_row0_col17" class="data row0 col17" >10
# -0.00</td>
#       <td id="T_3a72a_row0_col18" class="data row0 col18" >?
# -0.00</td>
#     </tr>
#     <tr>
#       <th id="T_3a72a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3a72a_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_3a72a_row1_col1" class="data row1 col1" >prob_diff</td>
#       <td id="T_3a72a_row1_col2" class="data row1 col2" >fixed</td>
#       <td id="T_3a72a_row1_col3" class="data row1 col3" >True</td>
#       <td id="T_3a72a_row1_col4" class="data row1 col4" >The
# 0.19</td>
#       <td id="T_3a72a_row1_col5" class="data row1 col5" >clock
# 0.19</td>
#       <td id="T_3a72a_row1_col6" class="data row1 col6" >shows
# 0.08</td>
#       <td id="T_3a72a_row1_col7" class="data row1 col7" >9
# 0.34</td>
#       <td id="T_3a72a_row1_col8" class="data row1 col8" >:
# 0.34</td>
#       <td id="T_3a72a_row1_col9" class="data row1 col9" >47
# 0.34</td>
#       <td id="T_3a72a_row1_col10" class="data row1 col10" >PM
# 0.18</td>
#       <td id="T_3a72a_row1_col11" class="data row1 col11" >.
# 0.18</td>
#       <td id="T_3a72a_row1_col12" class="data row1 col12" >How
# 0.19</td>
#       <td id="T_3a72a_row1_col13" class="data row1 col13" >many
# 0.19</td>
#       <td id="T_3a72a_row1_col14" class="data row1 col14" >minutes
# 0.14</td>
#       <td id="T_3a72a_row1_col15" class="data row1 col15" >'
# 0.07</td>
#       <td id="T_3a72a_row1_col16" class="data row1 col16" >til
# 0.07</td>
#       <td id="T_3a72a_row1_col17" class="data row1 col17" >10
# 0.18</td>
#       <td id="T_3a72a_row1_col18" class="data row1 col18" >?
# 0.18</td>
#     </tr>
#     <tr>
#       <th id="T_3a72a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3a72a_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_3a72a_row2_col1" class="data row2 col1" >cosine</td>
#       <td id="T_3a72a_row2_col2" class="data row2 col2" >nth_nearest (n=0)</td>
#       <td id="T_3a72a_row2_col3" class="data row2 col3" >True</td>
#       <td id="T_3a72a_row2_col4" class="data row2 col4" >The
# -0.00</td>
#       <td id="T_3a72a_row2_col5" class="data row2 col5" >clock
# -0.00</td>
#       <td id="T_3a72a_row2_col6" class="data row2 col6" >shows
# -0.00</td>
#       <td id="T_3a72a_row2_col7" class="data row2 col7" >9
# -0.00</td>
#       <td id="T_3a72a_row2_col8" class="data row2 col8" >:
# -0.00</td>
#       <td id="T_3a72a_row2_col9" class="data row2 col9" >47
# -0.00</td>
#       <td id="T_3a72a_row2_col10" class="data row2 col10" >PM
# -0.00</td>
#       <td id="T_3a72a_row2_col11" class="data row2 col11" >.
# -0.00</td>
#       <td id="T_3a72a_row2_col12" class="data row2 col12"

# %%
logger.print_attribution_matrix(exp_id=1, show_debug_cols=True)
# Out:
# Attribution matrix for experiment 1
# Attribution Strategy: cosine
# Perturbation strategy: fixed:
# Input Tokens (Rows) vs. Output Tokens (Columns)
# <style type="text/css">
# #T_9efa3_row0_col0, #T_9efa3_row1_col0, #T_9efa3_row8_col0, #T_9efa3_row9_col0 {
#   background-color: #fd7a37;
#   color: #f1f1f1;
# }
# #T_9efa3_row0_col1, #T_9efa3_row0_col2, #T_9efa3_row1_col1, #T_9efa3_row1_col2, #T_9efa3_row2_col0, #T_9efa3_row2_col1, #T_9efa3_row2_col2, #T_9efa3_row3_col1, #T_9efa3_row3_col2, #T_9efa3_row4_col1, #T_9efa3_row4_col2, #T_9efa3_row5_col1, #T_9efa3_row5_col2, #T_9efa3_row6_col0, #T_9efa3_row6_col1, #T_9efa3_row6_col2, #T_9efa3_row7_col0, #T_9efa3_row7_col1, #T_9efa3_row7_col2, #T_9efa3_row8_col1, #T_9efa3_row8_col2, #T_9efa3_row9_col1, #T_9efa3_row9_col2, #T_9efa3_row10_col0, #T_9efa3_row10_col1, #T_9efa3_row10_col2, #T_9efa3_row11_col0, #T_9efa3_row11_col1, #T_9efa3_row11_col2, #T_9efa3_row12_col0, #T_9efa3_row12_col1, #T_9efa3_row12_col2, #T_9efa3_row13_col0, #T_9efa3_row13_col1, #T_9efa3_row13_col2, #T_9efa3_row14_col0, #T_9efa3_row14_col1, #T_9efa3_row14_col2 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_9efa3_row3_col0, #T_9efa3_row4_col0, #T_9efa3_row5_col0 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9efa3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9efa3_level0_col0" class="col_heading level0 col0" >13 (0)</th>
#       <th id="T_9efa3_level0_col1" class="col_heading level0 col1" > minutes (1)</th>
#       <th id="T_9efa3_level0_col2" class="col_heading level0 col2" >. (2)</th>
#       <th id="T_9efa3_level0_col3" class="col_heading level0 col3" >perturbed_input</th>
#       <th id="T_9efa3_level0_col4" class="col_heading level0 col4" >perturbed_output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9efa3_level0_row0" class="row_heading level0 row0" >The (0)</th>
#       <td id="T_9efa3_row0_col0" class="data row0 col0" >0.147212</td>
#       <td id="T_9efa3_row0_col1" class="data row0 col1" >-0.000000</td>
#       <td id="T_9efa3_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_9efa3_row0_col3" class="data row0 col3" >  clock shows 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_9efa3_row0_col4" class="data row0 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_9efa3_level0_row1" class="row_heading level0 row1" >clock (1)</th>
#       <td id="T_9efa3_row1_col0" class="data row1 col0" >0.147212</td>
#       <td id="T_9efa3_row1_col1" class="data row1 col1" >-0.000000</td>
#       <td id="T_9efa3_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_9efa3_row1_col3" class="data row1 col3" >The  shows 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_9efa3_row1_col4" class="data row1 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_9efa3_level0_row2" class="row_heading level0 row2" >shows (2)</th>
#       <td id="T_9efa3_row2_col0" class="data row2 col0" >-0.000000</td>
#       <td id="T_9efa3_row2_col1" class="data row2 col1" >-0.000000</td>
#       <td id="T_9efa3_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_9efa3_row2_col3" class="data row2 col3" >The clock  9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_9efa3_row2_col4" class="data row2 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_9efa3_level0_row3" class="row_heading level0 row3" >9 (3)</th>
#       <td id="T_9efa3_row3_col0" class="data row3 col0" >0.274544</td>
#       <td id="T_9efa3_row3_col1" class="data row3 col1" >-0.000000</td>
#       <td id="T_9efa3_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_9efa3_row3_col3" class="data row3 col3" >The clock shows    PM. How many minutes 'til 10?</td>
#       <td id="T_9efa3_row3_col4" class="data row3 col4" >There are 120 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_9efa3_level0_row4" class="row_heading level0 row4" >: (4)</th>
#       <td id="T_9efa3_row4_col0" class="data row4 col0" >0.274544</td>
#       <td id="T_9efa3_row4_col1" class="data row4 col1" >-0.000000</td>
#       <td id="T_9efa3_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_9efa3_row4_col3" class="data row4 col3" >The clock shows    PM. How many minutes 'til 10?</td>
#       <td id="T_9efa3_row4_col4" class="data row4 col4" >There are 120 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_9efa3_level0_row5" class="row_heading level0 row5" >47 (5)</th>
#       <td id="T_9efa3_row5_col0" class="data row5 col0" >0.274544</td>
#       <td id="T_9efa3_row5_col1" class="data row5 col1" >-0.000000</td>
#       <td id="T_9efa3_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_9efa3_row5_col3" class="data row5 col3" >The clock shows    PM. How many minutes 'til 10?</td>
#       <td id="T_9efa3_row5_col4" class="data row5 col4" >There are 120 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_9efa3_level0_row6" class="row_heading level0 row6" >PM (6)</th>
#       <td id="T_9efa3_row6_col0" class="data row6 col0" >-0.000000</td>
#       <td id="T_9efa3_row6_col1" class="data row6 col1" >-0.000000</td>
#       <td id="T_9efa3_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_9efa3_row6_col3" class="data row6 col3" >The clock shows 9:47   How many minutes 'til 10?</td>
#       <td id="T_9efa3_row6_col4" class="data row6 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_9efa3_level0_row7" class="row_heading level0 row7" >. (7)</th>
#       <td id="T_9efa3_row7_col0" class="data row7 col0" >-0.000000</td>
#       <td id="T_9efa3_row7_col1" class="data row7 col1" >-0.000000</td>
#       <td id="T_9efa3_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_9efa3_row7_col3" class="data row7 col3" >The clock shows 9:47   How many minutes 'til 10?</td>
#       <td id="T_9efa3_row7_col4" class="data row7 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_9efa3_level0_row8" class="row_heading level0 row8" >How (8)</th>
#       <td id="T_9efa3_row8_col0" class="data row8 col0" >0.147212</td>
#       <td id="T_9efa3_row8_col1" class="data row8 col1" >-0.000000</td>
#       <td id="T_9efa3_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_9efa3_row8_col3" class="data row8 col3" >The clock shows 9:47 PM.  many minutes 'til 10?</td>
#       <td id="T_9efa3_row8_col4" class="data row8 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_9efa3_level0_row9" class="row_heading level0 row9" >many (9)</th>
#       <td id="T_9efa3_row9_col0" class="data row9 col0" >0.147212</td>
#       <td id="T_9efa3_row9_col1" class="data row9 col1" >-0.000000</td>
#       <td id="T_9efa3_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_9efa3_row9_col3" class="data row9 col3" >The clock shows 9:47 PM. How  minutes 'til 10?</td>
#       <td id="T_9efa3_row9_col4" class="data row9 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_9efa3_level0_row10" class="row_heading level0 row10" >minutes (10)</th>
#       <td id="T_9efa3_row10_col0" class="data row10 col0" >-0.000000</td>
#       <td id="T_9efa3_row10_col1" class="data row10 col1" >-0.000000</td>
#       <td id="T_9efa3_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_9efa3_row10_col3" class="data row10 col3" >The clock shows 9:47 PM. How many  'til 10?</td>
#       <td id="T_9efa3_row10_col4" class="data row10 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_9efa3_level0_row11" class="row_heading level0 row11" >' (11)</th>
#       <td id="T_9efa3_row11_col0" class="data row11 col0" >-0.000000</td>
#       <td id="T_9efa3_row11_col1" class="data row11 col1" >-0.000000</td>
#       <td id="T_9efa3_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_9efa3_row11_col3" class="data row11 col3" >The clock shows 9:47 PM. How many minutes   10?</td>
#       <td id="T_9efa3_row11_col4" class="data row11 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_9efa3_level0_row12" class="row_heading level0 row12" >til (12)</th>
#       <td id="T_9efa3_row12_col0" class="data row12 col0" >-0.000000</td>
#       <td id="T_9efa3_ro
# Attribution matrix for experiment 1
# Attribution Strategy: prob_diff
# Perturbation strategy: fixed:
# Input Tokens (Rows) vs. Output Tokens (Columns)
# <style type="text/css">
# #T_41b14_row0_col0, #T_41b14_row1_col0, #T_41b14_row8_col0, #T_41b14_row9_col0 {
#   background-color: #fec965;
#   color: #000000;
# }
# #T_41b14_row0_col1, #T_41b14_row2_col1, #T_41b14_row2_col2, #T_41b14_row3_col1, #T_41b14_row4_col1, #T_41b14_row5_col1, #T_41b14_row6_col1, #T_41b14_row7_col1, #T_41b14_row9_col1, #T_41b14_row11_col0, #T_41b14_row12_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_41b14_row0_col2 {
#   background-color: #e41c1d;
#   color: #f1f1f1;
# }
# #T_41b14_row1_col1 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_41b14_row1_col2 {
#   background-color: #dc151e;
#   color: #f1f1f1;
# }
# #T_41b14_row2_col0 {
#   background-color: #ffeda0;
#   color: #000000;
# }
# #T_41b14_row3_col0, #T_41b14_row4_col0, #T_41b14_row5_col0, #T_41b14_row13_col1, #T_41b14_row13_col2, #T_41b14_row14_col1, #T_41b14_row14_col2 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_41b14_row3_col2, #T_41b14_row4_col2, #T_41b14_row5_col2 {
#   background-color: #db141e;
#   color: #f1f1f1;
# }
# #T_41b14_row6_col0, #T_41b14_row7_col0, #T_41b14_row10_col0 {
#   background-color: #fede82;
#   color: #000000;
# }
# #T_41b14_row6_col2, #T_41b14_row7_col2 {
#   background-color: #d51020;
#   color: #f1f1f1;
# }
# #T_41b14_row8_col1 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_41b14_row8_col2 {
#   background-color: #f03523;
#   color: #f1f1f1;
# }
# #T_41b14_row9_col2 {
#   background-color: #e2191c;
#   color: #f1f1f1;
# }
# #T_41b14_row10_col1 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_41b14_row10_col2 {
#   background-color: #fd9f44;
#   color: #000000;
# }
# #T_41b14_row11_col1, #T_41b14_row12_col1 {
#   background-color: #fff3af;
#   color: #000000;
# }
# #T_41b14_row11_col2, #T_41b14_row12_col2 {
#   background-color: #ffefa4;
#   color: #000000;
# }
# #T_41b14_row13_col0, #T_41b14_row14_col0 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# </style>
# <table id="T_41b14">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41b14_level0_col0" class="col_heading level0 col0" >13 (0)</th>
#       <th id="T_41b14_level0_col1" class="col_heading level0 col1" > minutes (1)</th>
#       <th id="T_41b14_level0_col2" class="col_heading level0 col2" >. (2)</th>
#       <th id="T_41b14_level0_col3" class="col_heading level0 col3" >perturbed_input</th>
#       <th id="T_41b14_level0_col4" class="col_heading level0 col4" >perturbed_output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41b14_level0_row0" class="row_heading level0 row0" >The (0)</th>
#       <td id="T_41b14_row0_col0" class="data row0 col0" >0.279942</td>
#       <td id="T_41b14_row0_col1" class="data row0 col1" >0.000177</td>
#       <td id="T_41b14_row0_col2" class="data row0 col2" >0.294081</td>
#       <td id="T_41b14_row0_col3" class="data row0 col3" >  clock shows 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_41b14_row0_col4" class="data row0 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_41b14_level0_row1" class="row_heading level0 row1" >clock (1)</th>
#       <td id="T_41b14_row1_col0" class="data row1 col0" >0.279940</td>
#       <td id="T_41b14_row1_col1" class="data row1 col1" >0.000341</td>
#       <td id="T_41b14_row1_col2" class="data row1 col2" >0.301517</td>
#       <td id="T_41b14_row1_col3" class="data row1 col3" >The  shows 9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_41b14_row1_col4" class="data row1 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_41b14_level0_row2" class="row_heading level0 row2" >shows (2)</th>
#       <td id="T_41b14_row2_col0" class="data row2 col0" >0.170004</td>
#       <td id="T_41b14_row2_col1" class="data row2 col1" >0.000006</td>
#       <td id="T_41b14_row2_col2" class="data row2 col2" >0.076352</td>
#       <td id="T_41b14_row2_col3" class="data row2 col3" >The clock  9:47 PM. How many minutes 'til 10?</td>
#       <td id="T_41b14_row2_col4" class="data row2 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_41b14_level0_row3" class="row_heading level0 row3" >9 (3)</th>
#       <td id="T_41b14_row3_col0" class="data row3 col0" >0.719998</td>
#       <td id="T_41b14_row3_col1" class="data row3 col1" >0.000063</td>
#       <td id="T_41b14_row3_col2" class="data row3 col2" >0.303190</td>
#       <td id="T_41b14_row3_col3" class="data row3 col3" >The clock shows    PM. How many minutes 'til 10?</td>
#       <td id="T_41b14_row3_col4" class="data row3 col4" >There are 120 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_41b14_level0_row4" class="row_heading level0 row4" >: (4)</th>
#       <td id="T_41b14_row4_col0" class="data row4 col0" >0.719998</td>
#       <td id="T_41b14_row4_col1" class="data row4 col1" >0.000063</td>
#       <td id="T_41b14_row4_col2" class="data row4 col2" >0.303190</td>
#       <td id="T_41b14_row4_col3" class="data row4 col3" >The clock shows    PM. How many minutes 'til 10?</td>
#       <td id="T_41b14_row4_col4" class="data row4 col4" >There are 120 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_41b14_level0_row5" class="row_heading level0 row5" >47 (5)</th>
#       <td id="T_41b14_row5_col0" class="data row5 col0" >0.719998</td>
#       <td id="T_41b14_row5_col1" class="data row5 col1" >0.000063</td>
#       <td id="T_41b14_row5_col2" class="data row5 col2" >0.303190</td>
#       <td id="T_41b14_row5_col3" class="data row5 col3" >The clock shows    PM. How many minutes 'til 10?</td>
#       <td id="T_41b14_row5_col4" class="data row5 col4" >There are 120 minutes until 10 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_41b14_level0_row6" class="row_heading level0 row6" >PM (6)</th>
#       <td id="T_41b14_row6_col0" class="data row6 col0" >0.226407</td>
#       <td id="T_41b14_row6_col1" class="data row6 col1" >0.000040</td>
#       <td id="T_41b14_row6_col2" class="data row6 col2" >0.308993</td>
#       <td id="T_41b14_row6_col3" class="data row6 col3" >The clock shows 9:47   How many minutes 'til 10?</td>
#       <td id="T_41b14_row6_col4" class="data row6 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_41b14_level0_row7" class="row_heading level0 row7" >. (7)</th>
#       <td id="T_41b14_row7_col0" class="data row7 col0" >0.226407</td>
#       <td id="T_41b14_row7_col1" class="data row7 col1" >0.000040</td>
#       <td id="T_41b14_row7_col2" class="data row7 col2" >0.308993</td>
#       <td id="T_41b14_row7_col3" class="data row7 col3" >The clock shows 9:47   How many minutes 'til 10?</td>
#       <td id="T_41b14_row7_col4" class="data row7 col4" >13 minutes.</td>
#     </tr>
#     <tr>
#       <th id="T_41b14_level0_row8" class="row_heading level0 row8" >How (8)</th>
#       <td id="T_41b14_row8_col0" class="data row8 col0" >0.279977</td>
#       <td id="T_41b14_row8_col1" class="data row8 col1" >0.000424</td>
#       <td id="T_41b14_row8_col2" class="data row8 col2" >0.276330</td>
#       <td id="T_41b14_row8_col3" class="data row8 col3" >The clock shows 9:47 PM.  many minutes 'til 10?</td>
#       <td id="T_41b14_row8_col4" class="data row8 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_41b14_level0_row9" class="row_heading level0 row9" >many (9)</th>
#       <td id="T_41b14_row9_col0" class="data row9 col0" >0.279898</td>
#       <td id="T_41b14_row9_col1" class="data row9 col1" >0.000006</td>
#       <td id="T_41b14_row9_col2" class="data row9 col2" >0.295866</td>
#       <td id="T_41b14_row9_col3" class="data row9 col3" >The clock shows 9:47 PM. How  minutes 'til 10?</td>
#       <td id="T_41b14_row9_col4" class="data row9 col4" >There are 13 minutes until 10:00 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_41b14_level0_row10" class="row_heading level0 row10" >minutes (10)</th>
#       <td id="T_41b14_row10_col0" class="data row10 col0" >0.226115</td>
#       <td id="T_41b14_row10_col1" class="data row10 col1" >0.002101</td>
#       <td id="T_41b14_row10_col2" class="data row10 col2" >0.204414</td>
#       <td id="T_41b14_row10_col3" class="data row10 col3" >The clock shows 9:47 PM. How many  'til 10?</td>
#       <td id="T_41b14_row10_col4" class="data row10

# %%
logger.print_attribution_matrix(exp_id=11)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 logger.print_attribution_matrix(exp_id=11)
#
# File ~/PIZZA/attribution/experiment_logger.py:184, in ExperimentLogger.print_attribution_matrix(self, exp_id, attribution_strategy, show_debug_cols)
#     182     unique_strategies = self.df_token_attribution_matrix["attribution_strategy"].unique()
#     183     for strategy in unique_strategies:
# --> 184         self.print_attribution_matrix(
#     185             exp_id,
#     186             attribution_strategy=strategy,
#     187             show_debug_cols=show_debug_cols,
#     188         )
#     189 else:
#     190     # Filter the data for the specific experiment and attribution strategy
#     191     exp_data = self.df_token_attribution_matrix[
#     192         (self.df_token_attribution_matrix["exp_id"] == exp_id)
#     193         & (self.df_token_attribution_matrix["attribution_strategy"] == attribution_strategy)
#     194     ]
#
# File ~/PIZZA/attribution/experiment_logger.py:195, in ExperimentLogger.print_attribution_matrix(self, exp_id, attribution_strategy, show_debug_cols)
#     189 else:
#     190     # Filter the data for the specific experiment and attribution strategy
#     191     exp_data = self.df_token_attribution_matrix[
#     192         (self.df_token_attribution_matrix["exp_id"] == exp_id)
#     193         & (self.df_token_attribution_matrix["attribution_strategy"] == attribution_strategy)
#     194     ]
# --> 195     perturbation_strategy = self.df_experiments.loc[
#     196         self.df_experiments["exp_id"] == exp_id, "perturbation_strategy"
#     197     ].values[0]
#     199     # Create the pivot table for the matrix
#     200     matrix = exp_data.pivot(
#     201         index="input_token_pos", columns="output_token_pos", values="attr_score"
#     202     )
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
logger.df_experiments
# Out:
#     exp_id                                     original_input  \
# 0        1  The clock shows 9:47 PM. How many minutes 'til...
# 1        2  The clock shows 9:47 PM. How many minutes 'til...
# 2        3  The clock shows 9:47 PM. How many minutes 'til...
# 3        4  The clock shows 9:47 PM. How many minutes 'til...
# 4        5  The clock shows 9:47 PM. How many minutes 'til...
# 5        6  The clock shows 9:47 PM. How many minutes 'til...
# 6        7  The clock shows 9:47 PM. How many minutes 'til...
# 7        8  The clock shows 9:47 PM. How many minutes 'til...
# 8        9  The clock shows 9:47 PM. How many minutes 'til...
# 9       10  The clock shows 9:47 PM. How many minutes 'til...
# 10      11  The clock shows 9:47 PM. How many minutes 'til...
#
#                          original_output perturbation_strategy  \
# 0                            13 minutes.    nth_nearest (n=-1)
# 1   There are 13 minutes until 10:00 PM.    nth_nearest (n=-1)
# 2                            13 minutes.    nth_nearest (n=-1)
# 3                            13 minutes.    nth_nearest (n=-1)
# 4                            13 minutes.    nth_nearest (n=-1)
# 5                            13 minutes.    nth_nearest (n=-1)
# 6                            13 minutes.    nth_nearest (n=-1)
# 7   There are 13 minutes until 10:00 PM.    nth_nearest (n=-1)
# 8   There are 13 minutes until 10:00 PM.    nth_nearest (n=-1)
# 9   There are 13 minutes until 10:00 PM.    nth_nearest (n=-1)
# 10                           13 minutes.    nth_nearest (n=-1)
#
#     perturb_word_wise   duration
# 0                True  11.886951
# 1                True       None
# 2                True       None
# 3                True       None
# 4                True       None
# 5                True       None
# 6                True       None
# 7                True       None
# 8                True       None
# 9                True       None
# 10               True       None
